# %%
# SemanticRelatedWord is used to generate synonyms for each word
from DST.semantic_related_word.SemanticRelatedWord import SemanticRelatedWord
# WordDiscrimination is used to classify semantically related words
from DST.word_discrimination.WordDiscrimination import WordDiscrimination,default_classify_func
from os.path import dirname,join
from collections import defaultdict
import os
import logging
import json
import csv
import codecs
# Out:
# C:\Users\DELL\Anaconda3\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(name)s - %(levelname)s - %(message)s')
logging.getLogger("gensim").setLevel(logging.WARNING)
PROJ_PATH = dirname(os.getcwd())
DEFAULT_OUT_DIR = join(PROJ_PATH,"result")

#clean data， one line one sentence
with open (join(PROJ_PATH,"data/tags.txt"),mode="r",encoding="utf-8") as fr:
    data = [" ".join(line.strip().split())+"\n" for line in fr if len(line)>4]
    
with open (join(PROJ_PATH,"data/clean_tags.txt"),mode="w",encoding="utf-8") as fw:
    fw.writelines(data)
    
# Get terms (all words in clean_tags.txt)
vocab = defaultdict(int)
with open (join(PROJ_PATH,"data/clean_tags.txt"),mode="r",encoding="utf-8") as fr:
    for line in fr:
        for word in line.split():
            vocab[word]+=1

terms=[]
# Appear more than 5 times is considered as a term
for k,v in vocab.items():
    if v>5:
        terms.append(k)

# %%
# Get synonyms
sr = SemanticRelatedWord(domain_corpus_phrase_path=join(PROJ_PATH,"data/clean_tags.txt"), 
                         fasttext_path=join(PROJ_PATH,"models/fasttext/fasttext.model"), 
                         skipgram_path=join(PROJ_PATH,"models/skipgram/skipgram.model"), 
                         file_overwrite=True,topn_fasttext=8, 
                         topn_skipgram=15, similarity_threshold_fasttext=0.8,
                         similarity_threshold_skipgram=0.78, min_count=5, 
                         size=200, workers=8, window=5)
semantic_related_words = sr.getSemanticRelatedWords(terms=terms)
# Out:
# 2019-03-18 09:27:14,469 - DST.semantic_related_word.SemanticRelatedWord - INFO - train fasttext...
# 2019-03-18 09:28:12,222 - DST.semantic_related_word.SemanticRelatedWord - INFO - save fasttext to local...
# 2019-03-18 09:28:13,550 - DST.semantic_related_word.SemanticRelatedWord - INFO - train skipgram...
# 2019-03-18 09:28:28,971 - DST.semantic_related_word.SemanticRelatedWord - INFO - save skipgram to local...

# %%
# Classify synonyms, get abbreviation, synonym and other
wd = WordDiscrimination(classify_word_func=default_classify_func, 
                        semantic_related_types=["abbreviation", "other", "synonym"], 
                        group_dict=False, 
                        group_word_type="synonym", 
                        domain_vocab=None)
final_dict = wd.discriminate_words(semantic_related_words)

# %%
# View abbr
count = 0
for k,v in final_dict.items():
    if len(v["abbreviation"])>0:
        count+=1
        print(k,str(v["abbreviation"]))
print(count)
# Out:
# developers ['devs', 'devops']
# bacon ['bao']
# christmastree ['chritmas', 'chrismas']
# santaclaus ['santas']
# characterdesign ['charactern']
# skateboard ['skater']
# skateboarder ['skater']
# advertising ['ads']
# facebook ['fb']
# black-and-white ['bach', 'blackwhite']
# rocketboy ['rboy']
# animate ['ae']
# screenprint ['screent']
# avatar ['avaa']
# wordpress ['wp']
# flower ['flor']
# triangles ['tangle']
# bitcoin ['btc']
# sunrise ['suns']
# turkish ['tuk']
# javascript ['js']
# aftereffects ['affects']
# beltramo ['bltr']
# basketball ['bball']
# powerpoint ['ppt']
# francisco ['franco']
# miniature ['mature']
# contact ['cta']
# advertisment ['ads']
# bookshelf ['bose']
# psychedelic ['psychic']
# baseball ['bball']
# volunteer ['volt', 'vote']
# television ['tv']
# avatars ['avaa']
# adaptive ['api']
# statistics ['stats']
# balloons ['balls']
# cinema4d ['c4d']
# styleguide ['styled']
# bastard ['bard']
# brewery ['beer']
# champagne ['cane']
# cocktail ['coca']
# brooklyn ['bklyn']
# roar ['ra']
# 100dayui ['100ui']
# montana ['mona']
# cigarettes ['cigars']
# wireframes ['wires']
# vegetarian ['vegan']
# nevada ['nv']
# turkey ['tuk']
# candles ['cane']
# toilet ['toe']
# typefaces ['types']
# constellations ['collins']
# starbucks ['sucks']
# conveyor ['conor']
# minnesota ['mn']
# arizona ['az']
# services ['serve']
# tennessee ['tn']
# marketplace ['mart']
# smartisan ['sai']
# gladiator ['gator']
# burst ['but']
# after-effects ['affects']
# workinprogress ['wires', 'working']
# volkswagen ['van', 'vw']
# letterworks ['letters']
# philippines ['philips']
# cartooning ['carton']
# skyline ['skye']
# feelings ['feels']
# doctors ['docs']
# swimming ['swing']
# elite ['ee']
# virtual ['vr']
# armchair ['ac']
# conversation ['convert']
# pearls ['peas']
# popcorn ['porn']
# skyscraper ['skye']
# bathroom ['broom']
# consulting ['ci']
# themeforest ['themes']
# casestudy ['casey']
# tavern ['tn']
# rockabilly ['rocky']
# healthyfood ['healty']
# reveal ['reel']
# friendship ['fried']
# spotlight ['sight']
# motorcycles ['motors']
# statistic ['static', 'stats']
# lineicon ['linen']
# breakfast ['breast']
# helicopter ['helper']
# astronauts ['astros']
# columbine ['column']
# actions ['atn']
# beekeeper ['beep']
# timeless ['times']
# visualisation ['visuals']
# international ['internal']
# tables ['tabs']
# biking ['bing']
# brainstorm ['bro']
# dailyui001 ['day001']
# sphynx ['spy']
# birdsday ['birdy']
# steakhouse ['sake']
# wellness ['wells']
# copenhagen ['cph']
# tumbleweed ['tm']
# datavisualization ['dataviz']
# roommates ['rates']
# guidelines ['guides']
# tasar?m ['tm']
# billing ['bing']
# completed ['compte']
# citizen ['cn']
# businesscard ['bc']
# skateboarding ['skater']
# backgrounds ['bg']
# blacksmith ['blah']
# boeing ['bing']
# pencils ['pens']
# aftereffect ['ae']
# minimalis ['mnml']
# chopsticks ['chicks']
# ouroboros ['orbo']
# moutain ['mt']
# restoration ['rr']
# savage ['sage']
# aladdin ['alan']
# cyprus ['cpr']
# photobash ['photos']
# cottage ['cage']
# lightroom ['lr']
# colourandlines ['colours']
# academic ['acm']
# starshare ['stare']
# bulbasaur ['bulbs']
# sting ['sin']
# bodybuilding ['bulding']
# calligraphyquote ['caligraphy']
# contracting ['cr']
# indianapolis ['indians']
# strongman ['sm']
# beast ['bat']
# minneapolis ['mpls', 'mn']
# wireless ['wires']
# coca-cola ['cocoa']
# chinesenewyear ['cny']
# embossed ['embed']
# wroc?aw ['wc']
# advertisement ['ads']
# documents ['docs']
# cavaliers ['cavs']
# w?odarczyk ['wc']
# stardust ['stars']
# royalty ['ra']
# sonos ['sos']
# ernest ['ee']
# useless ['uss']
# carpenter ['center']
# thoughts ['thug']
# fragrance ['france']
# twilight ['tight']
# confectionary ['connary']
# treehouse ['trees']
# championships ['champs']
# skateboards ['skater', 'skates']
# musicians ['musica']
# blender3d ['b3d']
# beetles ['bees']
# cocacola ['cocoa', 'coco']
# benefit ['bi']
# starburst ['stars']
# productpage ['pdp']
# beijing ['bing']
# belgium ['bem']
# trumpet ['true']
# ?after-effects ['?ae']
# ?character ['?ae']
# dailyui004 ['day004']
# doughnut ['donut']
# devops ['devs']
# drippy ['dip']
# colosseum ['cole']
# bodoni ['boni']
# thunderbird ['ti']
# weaving ['wa']
# letterforms ['letters']
# compliments ['clients']
# tarzan ['tara', 'tan']
# intercom ['into']
# internal ['intel']
# leadership ['leads']
# designstudio ['desgn']
# fundraising ['funding']
# sullivan ['sivan']
# thumbnails ['thumbs']
# carpentry ['carpet']
# badminton ['baton']
# anatomy ['amy']
# thought ['thug']
# eccomerce ['ecom']
# chattanooga ['cn']
# saint ['st']
# brackets ['bets']
# adwords ['ads']
# 100daysofui ['100ui']
# managment ['manage']
# saturday ['say']
# dailyui007 ['day007']
# ideation ['ia']
# advertise ['ads']
# typographyinspired ['typograpy', 'typograhy']
# pennsylvania ['penny']
# successful ['sucess']
# pictograms ['pictos']
# rodeo ['roe']
# tablets ['tabs']
# beyond ['bond']
# dailyui005 ['day005']
# antenna ['anna']
# stopwatch ['swatch']
# lawyers ['laws']
# futbol ['fubo']
# handmadetype ['handtype']
# fuji ['fj']
# landrover ['lander']
# championship ['champs']
# cosplay ['cosy']
# cooperation ['ceo']
# independent ['indeed']
# prompt ['prop']
# sunburst ['suns']
# kentucky ['kc']
# creativemarket ['creativee']
# happynewyear ['hny']
# collie ['cole']
# handdrawntype ['handtype', 'handrawn']
# fujii ['fj']
# saint-petersburg ['sg', 'spb']
# mythological ['mythical']
# farmhouse ['farms']
# monograms ['monos']
# rapidgems ['rapids']
# neonlights ['nights']
# florence ['fence']
# sustainability ['stability']
# digitaldrawing ['dali']
# tanzania ['tanna']
# backyard ['bard']
# asteroid ['astro']
# singapore ['sg']
# brandits ['brad']
# champions ['champs']
# communicate ['commute']
# bartender ['bender']
# davidson ['davis']
# tartan ['tara']
# cubhaus ['cubs']
# doughnuts ['donut', 'donuts']
# demogorgon ['demon']
# coastal ['coal']
# bonsai ['boni']
# mistake ['mke']
# listings ['lists']
# camaro ['camo']
# dragutin ['dn']
# nikola ['nola']
# organiser ['organs']
# art-direction ['arte']
# boombox ['bomb']
# milano ['mia']
# problems ['pm']
# hunterxhunter ['hxh']
# countryside ['cone']
# dragonballsuper ['dragons']
# crowdfest ['ces', 'crows']
# wrench ['wc']
# sweepstakes ['sweets', 'sweet']
# miquido ['md']
# personalised ['personas']
# comfortable ['cable']
# mohammadfarik ['mh']
# bullseye ['bully']
# daredevil ['dd']
# blockstack ['btc']
# stalker ['se']
# elemental ['eel']
# shakespeare ['shaker', 'shaka']
# yomiyocai ['yoyo']
# tripadvisor ['trips']
# iphone-x ['ix']
# character-design ['charactern']
# machinelearning ['machining']
# staircase ['stairs']
# remodeling ['rm']
# namaste ['ne']
# canned ['cane']
# boring ['bing']
# bombs ['bob']
# simplistic ['sm']
# darkart ['dart']
# keyart ['kart']
# pizzeria ['pizza']
# marshmallows ['marshall']
# serengetee ['serene']
# congratulations ['congrats']
# bagels ['bags']
# indigenous ['indigo']
# constructions ['cr']
# kushtia ['ksa']
# blacklight ['blah']
# dreamworks ['dreams']
# userinterfacedesign ['uidesign']
# sanfrancisco ['sf', 'sai']
# eyecatching ['etching']
# interval ['intel']
# rechtbanktekenen ['rc']
# braids ['brad']
# moosesnowboards ['mesa']
# puppies ['pups']
# virtualreality ['vr']
# billiard ['bard']
# startrek ['stare']
# cartoonist ['carton']
# buckets ['bets']
# bulgarian ['brian']
# rokac ['ra']
# chocolates ['cocoa']
# thunderbolt ['turbo']
# experiential ['expert']
# gamestudio ['gameui']
# housewarming ['housing']
# colasse ['cole']
# mechanics ['mechas']
# survive ['suv']
# cobalt ['colt']
# tamilenglishtypography ['typograhy']
# tamil-typography ['typograhy']
# monroe ['moe']
# accelerator ['alt']
# wireframe-wednesday ['wires']
# straight ['sight']
# sioux ['six']
# doraemon ['demon']
# kidslitart ['kidlit']
# houseplants ['houses']
# campinas ['camps']
# motorcyclist ['motors']
# designthinking ['designing']
# ui-ux ['uix']
# commandments ['comments']
# portraiture ['potrait']
# crosshatch ['catch']
# super-sunday ['spend']
# element3d ['e3d']
# cockroach ['coca', 'cocoa']
# bruschetta ['bruce']
# simbol ['sm']
# heroimage ['homage']
# mohawk ['mh']
# matchmaking ['mk', 'mh']
# butterflies ['butts']
# alternativevision ['av', 'alternates']
# saved ['se']
# trolley ['te', 'troy']
# bandicoot ['bandit']
# marrakech ['mh']
# skyscrapers ['skye']
# hellboy ['hey']
# carpooling ['caring']
# branding. ['brand.']
# creativelogo ['creativo']
# dashboardhome ['dashbord', 'dasboard']
# abacus ['abc']
# satisfying ['saying']
# chatbots ['chats']
# buying ['bing']
# dungeon ['dune']
# creativeflyers ['creatives', 'creativee']
# wordpres ['wp']
# futebol ['fubo']
# chinatown ['cn']
# toothpaste ['taste']
# flowerillustration ['flor']
# styleframes ['styles']
# magazinedesign ['magazines']
# vtex ['vx']
# yearofthedog ['yeah']
# combo ['cb']
# boardgames ['boards']
# amiga ['amg']
# teenagers ['teens']
# pandecheng ['pdc']
# packagingdesign ['packagine']
# brewers ['beer']
# grapichdesign ['grapics']
# clockwork ['cr']
# sketchnotes ['sos']
# dragonballz ['dbz']
# blackonewhitegk ['blackwhite']
# mathematics ['maths']
# bilzerian ['brian']
# starting ['sting']
# valentinesday ['vday']
# snapback ['sack']
# colapen ['cole']
# dessine ['desi']
# cartoonish ['carton']
# horseman ['horn']
# panama ['pama']
# colagem ['cole']
# artforkids ['arto']
# vectoricons ['vectors']
# blossoms ['bloom']
# littlearchitecture ['lecture']
# everydaydesign ['everydays']
# netsuke ['nuke']
# cosmicode ['cosmo']
# visualizations ['visuals']
# trinetix ['trix']
# fashionmagazine ['fanzine']
# barkyn ['barn', 'bn']
# afteeffects ['affects']
# indianartist ['indians']
# agrofabrice ['af']
# installment ['instant']
# photoshopart ['photshop', 'photosop']
# portraitartist ['potrait', 'portraits']
# alternator ['aero']
# accumulator ['acm']
# infinitycoin ['infiniti']
# 440

# %%
abb_count = 0
for k,v in final_dict.items():
    if len(v["abbreviation"])>0:
        abb_count += len(v["abbreviation"])
print(abb_count)
# Out:
# 468

# %%
syn_count = 0
for k,v in final_dict.items():
    syn_count += len(v["synonym"])
print(syn_count)
# Out:
# 8966

# %%
# write into a json
f = open("final_thesaurus.json","w")
f.write(json.dumps(final_dict))
f.close()

# %%
A = []
for k,v in final_dict.items():
    abb = []
    other = []
    syn = []
    for i in range(0, len(v["abbreviation"])):
        abb.append(v["abbreviation"][i])
    for j in range(0, len(v["synonym"])):
        syn.append(v["synonym"][j])
    for z in range(0, len(v["other"])):
        other.append(v["other"][z])
    A.append([k, abb, syn, other])
A
# Out:
# [['003',
#   [],
#   [],
#   ['100ui',
#    '030',
#    '100daysofui',
#    '085',
#    '032',
#    'day004',
#    '004',
#    '008',
#    'dailyui008',
#    'error404',
#    'designchallenge',
#    'pagenotfound',
#    'dailyui003',
#    'comingsoon',
#    '048',
#    '4monthschallenge',
#    'errorpage',
#    '404page']],
#  ['30', [], [], ['day4', '030', '014', '011', 'day2', 'days', '-', 'day5']],
#  ['days',
#   [],
#   [],
#   ['day4', 'day3', 'day2', '36', '36days', '30', '100days', 'day1', 'day5']],
#  ['of', [], [], []],
#  ['ui',
#   [],
#   [],
#   ['ux.ui', 'ui.', 'uxui', 'ui-ux', '?ui', 'ux-ui', 'ui8', 'uix']],
#  ['colorful', [], ['colorful.', 'colourful', 'colorfull'], ['colorbeats']],
#  ['daily',
#   [],
#   [],
#   ['daily100',
#    'dailyui014',
#    'dailyui015',
#    'uidaily',
#    'dailyui007',
#    'dailyui011',
#    'dailyui100',
#    'daily-ui']],
#  ['landing', [], [], ['landingpage', 'landing-page', 'landingspage']],
#  ['page',
#   [],
#   ['page.', 'pager'],
#   ['fullpage',
#    'landing-page',
#    'loginpage',
#    'webpage',
#    'mainpage',
#    'landingspage']],
#  ['music',
#   [],
#   ['musical', 'musica'],
#   ['musician', 'musicians', 'musicapp', 'musiccloth']],
#  ['event', [], ['events'], []],
#  ['collection', [], ['collective', 'collect', 'collections'], []],
#  ['icon', [], ['icon.', 'icone', 'icono'], ['favicon', 'icons.', 'icon??i']],
#  ['iconography',
#   [],
#   [],
#   ['icon.',
#    'icone',
#    'icons.',
#    'iconpack',
#    'icono',
#    'icon??i',
#    'iconutopia',
#    'iconset']],
#  ['line', [], ['linen', 'lined'], ['wantline', 'one-line', 'lineal']],
#  ['online', [], [], ['onlineshop', 'onlineshopping', 'onlinestore']],
#  ['set', [], [], []],
#  ['shop', [], ['shops'], ['e-shop', 'eshop', 'shopping.', 'shoply']],
#  ['store', [], ['stores'], ['restore', 'onlinestore', 'storefront']],
#  ['canvas', [], ['canva'], ['acrylic']],
#  ['art', [], [], ['artph']],
#  ['design', [], ['design.', 'desig'], ['designzillas', 'designuxui']],
#  ['graffiti', [], [], ['calligraffiti', 'streetart']],
#  ['graphic',
#   [],
#   ['geographic', 'graphical', 'graphicart', 'graphics.'],
#   ['graphique', 'graphicgraphic', 'fpgraphic', 'info-graphic']],
#  ['hamburger', [], ['hamburg'], ['cook', 'eat', 'cheeseburger', 'burger']],
#  ['illustration',
#   [],
#   ['illustration??',
#    'illustratio',
#    'illlustration',
#    'illustratior',
#    'illustration.',
#    'i?llustration'],
#   ['mrugaillustration', 'llustration']],
#  ['stencil',
#   [],
#   [],
#   ['uppercase',
#    'slabserif',
#    'pairing',
#    'ttf',
#    'humanist',
#    'lowercase',
#    'slab',
#    'variable',
#    'tall',
#    'slab-serif',
#    'hco',
#    'otf',
#    'specimen',
#    'ramp',
#    'baskerville']],
#  ['calendar', [], ['calender'], ['calendar2018']],
#  ['date', [], [], ['datepicker']],
#  ['persian', [], [], ['italic']],
#  ['branding',
#   [],
#   ['branding.', 'brandits'],
#   ['selfbranding',
#    'brand.',
#    'self-branding',
#    'connorbranding',
#    'rebranding',
#    'citybranding']],
#  ['identity',
#   [],
#   ['indentity', 'identit?', 'identiy'],
#   ['identit?-visuelle',
#    'logoidentity',
#    'brand-identity',
#    'identidade',
#    'identidad']],
#  ['seed',
#   [],
#   ['seeds'],
#   ['mill',
#    'nourish',
#    'quilt',
#    'herbal',
#    'pots',
#    'greenhouse',
#    'magnolia',
#    'sprout',
#    'seaweed',
#    'vines',
#    'seamlesspattern',
#    'planter',
#    'medicinal',
#    'soil',
#    'leafs']],
#  ['spring', [], ['springs'], ['seasonal', 'tulip']],
#  ['sprout',
#   [],
#   [],
#   ['lily',
#    'symetry',
#    'poinsettia',
#    'begonia',
#    'nourish',
#    'aloe',
#    'vegetation',
#    'spruce',
#    'seeds',
#    'homegrown',
#    'pots',
#    'rotring',
#    'magnolia',
#    'herb',
#    'vines',
#    'twig',
#    'trout']],
#  ['glitchy',
#   [],
#   ['glitch', 'glitche', 'glitches'],
#   ['bboy',
#    'interpolation',
#    'shaders',
#    'generated',
#    'distorted',
#    'fontdesign',
#    'mont',
#    'spline',
#    'parametric',
#    '3dtitles',
#    'distort',
#    'handwrite',
#    'graphics.',
#    'chaos',
#    'glitchart']],
#  ['titles',
#   [],
#   ['title'],
#   ['paths',
#    'untitled',
#    '3dtitles',
#    'showreel',
#    'tricks',
#    'opener',
#    'videohive',
#    'openers',
#    'slideshow',
#    'movimiento',
#    'stomp',
#    'vlog',
#    'reel']],
#  ['budapest', [], [], ['grand']],
#  ['tipography',
#   [],
#   ['typography',
#    'typography.',
#    'tipograf?a',
#    'typgraphy',
#    'typographie',
#    'typeography'],
#   ['typedesign',
#    'swirls',
#    'wordplay',
#    'typographyart',
#    'sansserif',
#    'siontypography',
#    'vicente',
#    'typelove',
#    'typemate',
#    'typespire',
#    'writeup',
#    'numerals',
#    'stopmotion',
#    'sb-creative-studio',
#    'wavy',
#    'typism']],
#  ['t-shirt',
#   [],
#   ['tshirt', 'tee-shirt', 'tshirts', 't-shirts', 'teeshirt'],
#   ['sweatshirt', 'tee', 'shirt', 'shirts']],
#  ['blockchain',
#   [],
#   [],
#   ['cryptocurrency',
#    'ico',
#    'cryptocoin',
#    'btc',
#    'ethereum',
#    'crypto',
#    'currency',
#    'crypt',
#    'eth',
#    'cryptocurrencies',
#    'cryptocurrenty',
#    'bitcoin',
#    'decentralised',
#    'decentralized',
#    'cryptocurency',
#    'altcoin',
#    'ether']],
#  ['crypto',
#   [],
#   ['crypt'],
#   ['cryptocurrency',
#    'ico',
#    'coin',
#    'cryptocoin',
#    'ethereum',
#    'btc',
#    'blockchain',
#    'currency',
#    'cryptocurrencies',
#    'cryptocurrenty',
#    'bitcoin',
#    'cryptocurency',
#    'crypocurrency',
#    'exchange']],
#  ['cryptocurrency',
#   [],
#   ['cryptocurrencies', 'cryptocurrenty', 'cryptocurency', 'crypocurrency'],
#   ['etherium',
#    'ico',
#    'coin',
#    'cryptocoin',
#    'ethereum',
#    'wallet',
#    'crypto',
#    'blockchain',
#    'mining',
#    'btc',
#    'litecoin',
#    'currency',
#    'crypt',
#    'eth',
#    'bitcoin',
#    'exchange']],
#  ['ethereum',
#   [],
#   ['etherium', 'ethereal', 'etherum'],
#   ['bp',
#    'cryptocurrency',
#    'ico',
#    'bytecoin',
#    'cryptocoin',
#    'dogecoin',
#    'btc',
#    'blockchain',
#    'elix',
#    'crypto',
#    'litecoin',
#    'currency',
#    'eth',
#    'cryptocurrencies',
#    'monero',
#    'exchange',
#    'ether']],
#  ['isometric', [], ['isometry'], ['biometric', 'iso', 'sometric']],
#  ['lending',
#   [],
#   [],
#   ['litecoin',
#    'wealth',
#    'dollars',
#    'vending',
#    'sending',
#    'pending',
#    'stocks',
#    'financials',
#    'investing',
#    'spending',
#    'binding',
#    'expanse',
#    'finding',
#    'etherium',
#    'brending',
#    'forex',
#    'funding',
#    'investments',
#    'invest',
#    'advisory',
#    'mutual',
#    'leads',
#    'tokens']],
#  ['mining',
#   [],
#   [],
#   ['cryptocurrency',
#    'ico',
#    'trading',
#    'token',
#    'investing',
#    'dmit',
#    'litecoin',
#    'currency',
#    'cryptocurrencies',
#    'investment',
#    'lending',
#    'ethereum',
#    'exchange',
#    'ether',
#    'tokens']],
#  ['news', [], [], ['newsfeed']],
#  ['responsive', [], ['response'], ['responsibility', 'webresponsive', 'rwd']],
#  ['ux',
#   [],
#   [],
#   ['ux.ui', 'uiux', 'ui.', 'uxui', 'ui-ux', 'ux-ui', 'ux.', '?ux']],
#  ['web',
#   [],
#   [],
#   ['webui',
#    'webkul',
#    'website',
#    'webite',
#    'webpsd',
#    'webcam',
#    'webpage',
#    'web-app',
#    'webiste',
#    'web-site']],
#  ['website',
#   [],
#   ['website.', 'webite', 'wesite', 'webiste', 'websites', 'web-site'],
#   ['webui', 'site', 'web']],
#  ['anchor', [], [], ['hook']],
#  ['challenge',
#   [],
#   ['chagllenge', 'chellenge'],
#   ['daily-logo-challenge',
#    'designchallenge',
#    'dailychallenge',
#    'weeklychallenge',
#    '100daychallenge',
#    '4monthschallenge']],
#  ['logo',
#   [],
#   ['logo.'],
#   ['logo2018',
#    'logodlc',
#    'logoset',
#    'glogo',
#    'logogrid',
#    'logotipe',
#    '?logo']],
#  ['thirtylogos',
#   [],
#   ['thirty-logos', 'thirtylogo'],
#   ['30logoschallenge',
#    '99logos',
#    'thegrind',
#    'thirtylogoschallenge',
#    '30logos',
#    'sparked',
#    'logos',
#    'thirty',
#    'logochallenge']],
#  ['thirtylogoschallenge',
#   [],
#   [],
#   ['twitchy',
#    'pups',
#    '1-800-rosebud',
#    '30logoschallenge',
#    'thegrind',
#    'adobeiluustrator',
#    'wenatchee',
#    'thirtylogos',
#    'deadbeat',
#    'sparked',
#    'hampton',
#    'dailylogochallenge',
#    'cove',
#    '30logos',
#    'twitchyrabbit',
#    'daily-logo-challenge',
#    'thirty',
#    'thirty-logos',
#    'thirtylogo',
#    'logochallenge']],
#  ['calligraphy',
#   [],
#   ['caligraphy', 'callygraphy', 'calligram', 'calligraphic'],
#   ['calligraffiti', 'caligrafia', 'kaligrafia', 'calligraphyquote']],
#  ['logotype',
#   [],
#   ['logotipo', 'logotypes', 'logotipe', 'logotyp'],
#   ['monologotype', 'logo.', 'isotype']],
#  ['rgb', [], [], []],
#  ['blue', [], [], []],
#  ['single', [], ['singles', 'singlet'], ['singh']],
#  ['weight',
#   [],
#   ['weights'],
#   ['lifting',
#    'weightlifting',
#    'bodyweight',
#    'weightloss',
#    'height',
#    'loss',
#    'squat']],
#  ['dj', [], [], ['djo', 'electro']],
#  ['fever',
#   [],
#   ['forever'],
#   ['vanity',
#    'iampommes',
#    'ever',
#    'trans',
#    'cajun',
#    'dip',
#    'never',
#    'ict',
#    'forget',
#    'cole',
#    'misty',
#    'beau',
#    'resurrection',
#    'peep',
#    '1970',
#    'drummers',
#    'tomorrow']],
#  ['lettering',
#   [],
#   ['letterin'],
#   ['letteringtype',
#    'hand-lettering',
#    'customlettering',
#    'scriptlettering',
#    'brushlettering',
#    'hahdlettering',
#    'hashtaglettering']],
#  ['tag', [], ['tags'], []],
#  ['destination',
#   [],
#   ['destinations'],
#   ['insider',
#    'urlaub',
#    'travelers',
#    'holidaycheck',
#    'hotels',
#    'charter',
#    'backpacking',
#    'cruise',
#    'cruises',
#    'coordination',
#    'tours',
#    'dubnation',
#    'explanation',
#    'aviation',
#    'accommodation',
#    'nation',
#    'procrastination',
#    'flights',
#    'inn',
#    'hostel']],
#  ['hike',
#   [],
#   ['hiker'],
#   ['outside',
#    'airstream',
#    'hammock',
#    'campfire',
#    'hiking',
#    'camping',
#    'recreation',
#    'climb',
#    'kayak',
#    'backpacking',
#    'canoe']],
#  ['mountain',
#   [],
#   ['mountains', 'moutain', 'montain'],
#   ['designmountain', 'mountaineering', 'fountain', 'mount']],
#  ['bike',
#   [],
#   ['biker', 'bikes'],
#   ['cycling', 'bicycle', 'e-bike', 'bikers', 'bicycles', 'cyclist']],
#  ['outdoors', [], ['outdoor'], ['hammock', 'hiking', 'wilderness', 'kayak']],
#  ['photoshop',
#   [],
#   ['photoshoot', 'photshop', 'photoshop.', 'photoshopart', 'photosop'],
#   ['adobephotoshop']],
#  ['unknown',
#   [],
#   [],
#   ['scalzo',
#    'roadster',
#    'uf',
#    'unc',
#    'spacetravel',
#    'warframe',
#    'vs',
#    'starts',
#    'vx',
#    'rift',
#    'mtv',
#    'teleport',
#    'sputnik',
#    'volley',
#    'nz',
#    'roland',
#    'spacedchallange',
#    'volvo',
#    'unreal',
#    'shooter',
#    'zipl',
#    'nvidia']],
#  ['club', [], ['clubs'], ['clubbing']],
#  ['distortion',
#   [],
#   ['distorted', 'distort'],
#   ['shaders',
#    'abstraction',
#    'cogwurx',
#    'contempoary',
#    'glitchy',
#    'expressionism',
#    'ambient',
#    'bauhaus',
#    'animography',
#    'brights',
#    'colorbeats',
#    'chaos',
#    'glitchart',
#    'experimental']],
#  ['glitch', [], ['glitches', 'glitche', 'glitchy'], ['glitchart']],
#  ['input',
#   [],
#   ['inputs'],
#   ['dialog',
#    'reset',
#    'dropdown',
#    'modal',
#    'password',
#    'forgot',
#    'hint',
#    'modals',
#    'inbox',
#    'checkbox',
#    'fields',
#    'forms']],
#  ['night',
#   [],
#   ['nights'],
#   ['moonlight', 'midnight', 'nightmare', 'nightclub', 'nighttime']],
#  ['techno',
#   [],
#   [],
#   ['toske',
#    'technique',
#    'trance',
#    'techniques',
#    'producer',
#    'rave',
#    'technology',
#    'technologies']],
#  ['animation',
#   [],
#   ['animation.'],
#   ['celanimation',
#    'animation2d',
#    'punanimation',
#    'cellanimation',
#    '3danimation',
#    '2danimation',
#    '?animation']],
#  ['bank',
#   [],
#   [],
#   ['fintech',
#    'budget',
#    'banking',
#    'banco',
#    'finance',
#    'neobank',
#    'loan',
#    'countingup',
#    'finances',
#    'alfabank',
#    'borrow',
#    'alfa-bank']],
#  ['eagle', [], ['eagles'], ['beagle', 'hawk', 'buffalo']],
#  ['pulse',
#   [],
#   [],
#   ['scanner',
#    'radial',
#    'percent',
#    'optic',
#    'volume',
#    'wearables',
#    'synapse',
#    'robotic',
#    'vocal',
#    'pull',
#    'impulse']],
#  ['scanner',
#   [],
#   [],
#   ['transparency',
#    'percent',
#    'nodes',
#    'vd',
#    'sorting',
#    'pulse',
#    'unlock',
#    'robotic',
#    'variations',
#    'strictly']],
#  ['search', [], [], ['searchbar', 'results', 'searching']],
#  ['security',
#   [],
#   [],
#   ['protection', 'purity', 'cybersecurity', 'safe', 'secure']],
#  ['foot', [], ['foo'], ['footbal', 'bigfoot', 'barbell', 'badminton']],
#  ['grape',
#   [],
#   ['grapes'],
#   ['kraft',
#    'lime',
#    'garnish',
#    'redruby',
#    'harvest',
#    'caramel',
#    'flavours',
#    'sour',
#    'juicy',
#    'basil',
#    'citrus',
#    'flavors',
#    'cashew',
#    'ricochico',
#    'flavor',
#    'grapefruit']],
#  ['lineart',
#   [],
#   ['line-art', 'lineal', 'linear'],
#   ['linen', 'fineart', 'linework', 'lined', 'lineicon']],
#  ['line-art',
#   [],
#   ['lineart', 'linear'],
#   ['lineal',
#    'utilitarian',
#    'intersect',
#    'lineicon',
#    'vetor',
#    'linen',
#    'knot',
#    'sigil',
#    'one-line',
#    'rays',
#    'magnetic',
#    'sparrow',
#    'rokac',
#    'zooom',
#    'geometrical',
#    'lineup',
#    'jamaica',
#    'linework',
#    'lined']],
#  ['wine', [], [], ['winery', 'swine']],
#  ['app',
#   [],
#   ['app.', 'apps'],
#   ['appui', 'app??i', 'apply', 'application', 'appmobile', 'iosapp']],
#  ['developers',
#   ['devs', 'devops'],
#   ['develop', 'developing', 'devloper', 'development', 'developer'],
#   ['developement', 'salesforce', 'webdeveloper', 'sap', 'coder']],
#  ['australia', [], ['australian', 'austria'], ['aussie']],
#  ['apps',
#   [],
#   ['app.', 'app'],
#   ['appui', 'approach', 'apply', 'app??i', 'dapper', 'application']],
#  ['business',
#   [],
#   ['businessman', 'businesses', 'busines'],
#   ['business-logo',
#    'business-card',
#    'businessfinance',
#    'businesscards',
#    'businesscard']],
#  ['dapper',
#   [],
#   [],
#   ['cosmicode',
#    'atlassian',
#    'hubspot',
#    'classifieds',
#    'prototypes',
#    'edtech',
#    'e-comerce',
#    'dapp',
#    'xamarin',
#    'accounts',
#    'campaigns',
#    'driven',
#    'optimisation',
#    'apps',
#    'applications',
#    'perth']],
#  ['mobile',
#   [],
#   ['mobil', 'mobileui'],
#   ['mobilefirst',
#    't-mobile',
#    'mobile-app',
#    'mobileapps',
#    'mobilapp',
#    'appmobile']],
#  ['perth',
#   [],
#   [],
#   ['udemy',
#    'atlassian',
#    'onepager',
#    'hi-fi',
#    'idap',
#    'forums',
#    'beacons',
#    'routes',
#    'driven',
#    'optimisation',
#    'counseling',
#    'shopping.',
#    'passive',
#    'mutual',
#    'transfers',
#    'b2c']],
#  ['tech',
#   [],
#   [],
#   ['technique', 'technology', 'nanotechnology', 'tecnology', 'technologies']],
#  ['analytics',
#   [],
#   ['analysis', 'analytic'],
#   ['bigdata',
#    'database',
#    '018',
#    'charting',
#    'dasboard',
#    'analyse',
#    'audience',
#    'barchart',
#    'chart',
#    'datavis',
#    'charts',
#    'gauge',
#    'backend',
#    'piechart',
#    'analyst',
#    'analyze',
#    'insights']],
#  ['colors',
#   [],
#   ['colours', 'color'],
#   ['colorblock', 'colorful.', 'colorbeats', 'colour']],
#  ['dashboard',
#   [],
#   ['dashboards', 'dashbord', 'dasboard'],
#   ['dashboardhome', 'admin', 'dashboard-saturday', 'dash']],
#  ['media', [], [], ['mixedmedia', 'socialmedia']],
#  ['tv', [], [], ['tvc', 'television']],
#  ['platform', [], ['platforms', 'platformer'], []],
#  ['brand',
#   [],
#   ['brandev', 'brandom', 'brands', 'brand.'],
#   ['branddev', 'branding.', 'brand-identity', 'brandits']],
#  ['brandidentity',
#   [],
#   ['brandingidentity', 'brand-identity', 'branidentity'],
#   ['designlogo',
#    'smartsign',
#    'identitydesign',
#    'customlogo',
#    'identit?-visuelle',
#    'logoidentity',
#    'branddesign',
#    'connorbranding',
#    'logoinspiration',
#    'designideas',
#    'corporateidentity',
#    'brand-design',
#    'brandits']],
#  ['creative',
#   [],
#   ['creativee', 'creativo', 'creatives'],
#   ['alickreative',
#    'kevincreative',
#    'weeklycreatives',
#    'creativemarket',
#    'creativelogo']],
#  ['creatives',
#   [],
#   ['creative', 'creativee', 'creativo'],
#   ['alickreative',
#    'burma',
#    'bristol',
#    'creatividad',
#    'grapics',
#    'basfranken',
#    'saeed',
#    'show-off',
#    'gr?fico',
#    'creativeflyers',
#    'sub-brand',
#    'faizan',
#    'cheymarket',
#    'brand-design',
#    'bestnine',
#    'artdirector',
#    'creativemarket',
#    'andreadabene',
#    'creativelogo',
#    'adv']],
#  ['designers',
#   [],
#   ['designteam', 'designer'],
#   ['c4dfordesigners',
#    '3dfordesigners',
#    'designer??rt',
#    'drafts',
#    'hire',
#    'jondesigner',
#    'esigner',
#    'ui-designer']],
#  ['designinspiration',
#   [],
#   ['designspiration'],
#   ['inspiration',
#    'dailyinspiration',
#    'uiinspiration',
#    'logoinspiration',
#    'designtips',
#    'uxinspiration',
#    'uiinspirations',
#    'colima']],
#  ['graphicdesign',
#   [],
#   ['graphicdesigns', 'graphic-design', 'graphicdesigner', 'grapichdesign'],
#   ['belcdesign', 'olikdesign', 'n3design', '@design']],
#  ['bacon',
#   ['bao'],
#   ['beacon', 'balcony'],
#   ['butter',
#    'baconnais',
#    'chewy',
#    'broccoli',
#    'bread',
#    'bae',
#    'croissant',
#    'burrito',
#    'baku',
#    'bake',
#    'bruce',
#    'crumbs',
#    'fry',
#    'artisanal',
#    'beef',
#    'bite',
#    'cheesy',
#    'bagels',
#    'cheeseburger',
#    'fried']],
#  ['color',
#   [],
#   ['colours', 'colors', 'colour'],
#   ['onecolor', 'colorblock', 'colorful.', 'colorbeats', 'flatcolor']],
#  ['palette', [], ['palettes'], []],
#  ['theory',
#   [],
#   [],
#   ['the80s',
#    'offgrid',
#    'blocking',
#    'furr',
#    'society6',
#    'iconart',
#    'geisha',
#    '100posters',
#    'narrative',
#    'indianartist',
#    'illus',
#    'homeware',
#    'ballasiotes',
#    'curiosity',
#    'magritte',
#    'comissioned']],
#  ['colour',
#   [],
#   ['coloured', 'colours', 'color'],
#   ['colouring', 'colourful', 'colorful.', 'colors', 'colorbeats']],
#  ['css', [], [], ['hfm', 'html', 'javascript', 'htmlcss', 'css3']],
#  ['eggs',
#   [],
#   ['egg'],
#   ['coconut',
#    'dessert',
#    'eggplant',
#    'foodtruck',
#    'foodporn',
#    'broccoli',
#    'bread',
#    'croissant',
#    'flavour',
#    'fry',
#    'breakfast',
#    'biscuits',
#    'cheesy',
#    'carton',
#    'ice-cream',
#    'berry',
#    'ketchup',
#    'bacon',
#    'fried',
#    'fhc30']],
#  ['food',
#   [],
#   ['foods', 'foo'],
#   ['foodie', 'foodtruck', 'fastfood', 'foodshed', 'foodporn']],
#  ['minimal',
#   [],
#   ['minimalis', 'minimap', 'minimalist', 'minimum', 'minimal.'],
#   ['?minimal', 'minimal-monday', 'minimalistic']],
#  ['palettes',
#   [],
#   ['palette'],
#   ['skew',
#    'guidebook',
#    'swatches',
#    'pierre',
#    'bgmrodotec',
#    'may',
#    'blocking',
#    'classification',
#    'duolingo',
#    'ellipse',
#    'analogous',
#    'stylesheet',
#    'homeware',
#    'caution',
#    'sessions']],
#  ['monochrome', [], [], ['monocle', 'monochromatic']],
#  ['pack', [], ['pac'], ['packet']],
#  ['uidesign',
#   [],
#   ['uxdesign', 'uidesigner', 'ui-design', 'uiuxdesign', 'ux-design'],
#   ['weatherapp',
#    'interfacedesign',
#    'userexperiance',
#    'websitedesign',
#    'uiinspiration',
#    'onboardingdesign',
#    'userinterfacedesign',
#    'web-design',
#    'uxinspiration',
#    'uitrends',
#    'mobiledesign',
#    're-design',
#    'userinterface']],
#  ['uxdesign',
#   [],
#   ['uidesigner',
#    'uidesign',
#    'ui-design',
#    'uxdesigner',
#    'uiuxdesign',
#    'ux-design'],
#   ['weatherapp',
#    'userexperiance',
#    'uiinspiration',
#    'userinterfacedesign',
#    'web-design',
#    'uitrends',
#    'userexperience',
#    're-design',
#    'userinterface',
#    'interfacedesign',
#    'designthinking',
#    'webdeveloper',
#    'websitedesign',
#    'mobiledesign',
#    'uxinspiration']],
#  ['bamboo',
#   [],
#   [],
#   ['whoosh',
#    'footprint',
#    'logodlc',
#    'hampton',
#    'kangaroo',
#    'airballoon',
#    'foxy',
#    'exploring',
#    'app-icon',
#    'baloon',
#    'dlc']],
#  ['black',
#   [],
#   [],
#   ['blackpanther',
#    'blackbeard',
#    'blacknwhite',
#    'black-and-white',
#    'blackjack',
#    'blackwhite',
#    'black-white',
#    'blackmirror']],
#  ['character',
#   [],
#   ['charactern',
#    'character.',
#    'charcter',
#    'caracter',
#    'charachter',
#    'characters'],
#   ['3dcharacter', '?character']],
#  ['digital',
#   [],
#   ['digit', 'digtal', 'digits'],
#   ['digitalpaint', 'dig', 'digital-art', 'f1digitals', 'okdigital']],
#  ['game',
#   [],
#   ['gamer', 'games'],
#   ['gameloft', 'gameui', 'gamedev', 'gamepad', 'gameart', 'bingogame']],
#  ['panda', [], ['pandas'], ['pandaearth']],
#  ['slot', [], ['slots'], []],
#  ['white', [], [], ['offwhite']],
#  ['c4d', [], [], ['cinema4d', '4d']],
#  ['gif', [], ['gifs'], []],
#  ['iphone',
#   [],
#   ['iphones', 'iphone-x', 'iphonex'],
#   ['iphone6', 'iphone8', 'iphone10', 'ios11', 'x']],
#  ['homepage',
#   [],
#   [],
#   ['fullpage',
#    'landing-page',
#    'onepage',
#    'landingpage',
#    'guidepage',
#    'frontpage',
#    'landingspage']],
#  ['interaction',
#   [],
#   ['interactions', 'interactive'],
#   ['microinteractions',
#    'micro-interaction',
#    '365interactions',
#    'microinteraction',
#    'interactiondesign',
#    'dezinsinteractive']],
#  ['motion',
#   [],
#   ['motionui'],
#   ['co-motion', 'ramotion', '?motion', 'lotion', 'motion-graphics']],
#  ['magazine',
#   [],
#   ['magazines'],
#   ['magazinecover',
#    'bookazine',
#    'fashionmagazine',
#    'zine',
#    'magazinedesign',
#    'fanzine']],
#  ['conceptual',
#   [],
#   ['conceptart', 'concepts', 'conceptat', 'conceptdot', 'concept-art'],
#   ['alexei']],
#  ['editorial', [], [], ['editorialillustration', 'editorial-illustration']],
#  ['pattern',
#   [],
#   ['patter', 'patterns'],
#   ['surfacepattern', 'seamlesspattern']],
#  ['sofia',
#   [],
#   [],
#   ['magazinecover',
#    'ninaifreitas',
#    'bulletin',
#    'sita',
#    'millennials',
#    'stampa',
#    'daca',
#    'munchies',
#    'recife']],
#  ['sita',
#   [],
#   [],
#   ['surfacepattern',
#    'refugees',
#    'wildflowers',
#    'line-drawing',
#    'stampa',
#    'daca',
#    'wichita',
#    'modernity',
#    'surfrider',
#    'um',
#    'seamlesspattern',
#    'recife',
#    'queijo',
#    'estampa',
#    'sofia',
#    'tallahassee']],
#  ['foodapp',
#   [],
#   ['foodart'],
#   ['appui',
#    'inapp',
#    'kfc',
#    'recipies',
#    'app-design',
#    'mira',
#    'healty',
#    'foodporn',
#    'convinient',
#    'foods',
#    'automate',
#    'eat24',
#    'foodie',
#    'appmobile',
#    'iosapp',
#    'andorid',
#    'pyszne',
#    'prepare',
#    'dishes',
#    '7ninjas']],
#  ['layout', [], ['layouts'], ['weblayout']],
#  ['onboarding',
#   [],
#   ['onboard', 'on-boarding'],
#   ['hoarding',
#    'storyboarding',
#    'boarding',
#    'boardingpass',
#    'onboardingdesign',
#    'walkthrough']],
#  ['apparel', [], [], []],
#  ['football',
#   [],
#   ['footbal', 'footballer'],
#   ['soccer', 'basketball', 'bball', 'softball', 'nfl']],
#  ['badge', [], ['badges', 'badger'], []],
#  ['kit', [], [], []],
#  ['logos',
#   [],
#   ['logoset', 'logo.'],
#   ['logodlc',
#    '99logos',
#    '30logos',
#    'thirtylogos',
#    'logoicon',
#    'thirty-logos']],
#  ['shield', [], [], ['windshield', 'ti']],
#  ['soccer', [], [], ['footballer', 'softball', 'footbal', 'football']],
#  ['santa',
#   [],
#   ['santas'],
#   ['claus',
#    'santacruz',
#    'presents',
#    'sleigh',
#    'reindeer',
#    'santaclaus',
#    'x-mas',
#    'snowman',
#    'merry',
#    'xmas']],
#  ['station', [], ['static'], ['workstation', 'rotation', 'reputation']],
#  ['icons',
#   [],
#   ['icon.', 'icone', 'icons.', 'icono', 'iconset'],
#   ['iconsets', 'icon??i']],
#  ['ios', [], [], ['iocn', 'ios11', 'iosapp']],
#  ['social',
#   [],
#   [],
#   ['socialapp', 'socialshare', 'socialmedia', 'socialbakers']],
#  ['abstract', [], ['abstractart', 'abstrack', 'abstraction'], ['abs']],
#  ['gradient', [], ['gradiente', 'gradiant', 'gradients', 'gradient.'], []],
#  ['illustrator',
#   [],
#   ['iillustrator',
#    'iiiustrator',
#    'illlustrator',
#    'illsutrator',
#    'ilustrator',
#    'illustrators',
#    'illustraton'],
#   ['adobe-illustrator']],
#  ['noise', [], ['noisy'], []],
#  ['poster',
#   [],
#   ['posters'],
#   ['eposter',
#    'movieposter',
#    'blankposter',
#    'posterxday',
#    'gigposter',
#    'posterevryday',
#    'posteraday']],
#  ['print',
#   [],
#   ['print.', 'prints', 'printed'],
#   ['sprint', 'printing', 'newsprint', 'artprint', 'printable']],
#  ['shape', [], ['shapes', 'shaper'], ['deepshape']],
#  ['typography',
#   [],
#   ['typography.',
#    'typogaphy',
#    'typographie',
#    'typograhy',
#    'typograpy',
#    'typograph',
#    'typographyart'],
#   ['siontypography']],
#  ['aiste',
#   [],
#   [],
#   ['latter',
#    'bach',
#    'gradiente',
#    'acronym',
#    'baconnais',
#    'assam',
#    'poroto',
#    'constructions',
#    'amitspro',
#    'brand-identity',
#    'identidadevisual',
#    '3xter',
#    'tieatie',
#    'nb',
#    'jk',
#    'andrea']],
#  ['agency', [], ['agence'], ['moodagency']],
#  ['illusion',
#   [],
#   ['illusions', 'illusign'],
#   ['penrose', 'escher', 'impossible', 'optical', 'op', 'illus', 'prism']],
#  ['mark', [], [], []],
#  ['play', [], ['playa'], ['playdom', 'playback', 'playboy']],
#  ['button', [], ['buttons'], []],
#  ['tieatie',
#   [],
#   [],
#   ['pj',
#    'latter',
#    'mase',
#    'mv',
#    'tsverava',
#    'rr',
#    'rm',
#    'combo',
#    'mh',
#    'jk',
#    'kk',
#    'jp',
#    'nb',
#    'sm',
#    'gradiente',
#    'logoset',
#    'logo-concept',
#    'hunap',
#    'cr',
#    'mk',
#    'fatihkovac',
#    'esense']],
#  ['unique', [], [], ['jely', 'uniqlo']],
#  ['publishing',
#   [],
#   ['publisher', 'publish', 'publishers', 'published'],
#   ['narrative', 'publication', 'e-book']],
#  ['adventure',
#   [],
#   ['adventurer', 'adventures'],
#   ['advent', 'advencher', 'venture']],
#  ['friends',
#   [],
#   ['friend', 'fried', 'friendship', 'fries', 'friendly'],
#   ['girlfriend', 'boyfriend']],
#  ['fun', [], [], []],
#  ['loop', [], ['loops'], ['looping', 'looped', '?loop']],
#  ['skate',
#   [],
#   ['skater', 'skates'],
#   ['skateboard',
#    'skateshop',
#    'skateboarding',
#    'skateboarder',
#    'skatedeck',
#    'longboard',
#    'skateboards']],
#  ['sports',
#   [],
#   ['sport', 'sporty'],
#   ['sportlogo', 'sportswear', 'sportgirl', 'sportslogo', 'e-sports']],
#  ['hand', [], [], ['handdone', 'drawn', 'handrawn']],
#  ['drawn',
#   [],
#   [],
#   ['prawn', 'drawning', 'handrawn', 'hand', 'handdrawn', 'hand-drawn']],
#  ['oak', [], [], ['oa', 'mt']],
#  ['tree', [], ['trees'], ['palmtree', 'treehouse']],
#  ['direction',
#   [],
#   ['director', 'directing', 'directions'],
#   ['art-direction', 'correction', 'direct', 'artdirection']],
#  ['spiritual',
#   [],
#   ['spirituality'],
#   ['tropics',
#    'walrus',
#    'swamp',
#    'snakes',
#    'sparkly',
#    'ritual',
#    'monkeys',
#    'waterdrop',
#    'silhouettes',
#    'serenity',
#    'spirited',
#    'witchy',
#    'rafikillustrate',
#    'she',
#    'remake',
#    'swimsuit',
#    'spirit',
#    'pieces']],
#  ['beach', [], [], ['beacon']],
#  ['french', [], ['frenchie'], []],
#  ['riviera',
#   [],
#   [],
#   ['silpo',
#    'piaggio',
#    'danny',
#    'revolver',
#    '1970s',
#    'retrofuturism',
#    'tapes',
#    'scrabble',
#    'ww2',
#    'midcenturymodern',
#    'n.petrovic',
#    'monaco',
#    'mcm',
#    'visfire',
#    'ukiyo-e',
#    'nv',
#    'googie',
#    'wwii',
#    'rifftrax',
#    'zippo',
#    'kiev',
#    'vintagebundle',
#    'oldstyle']],
#  ['sun',
#   [],
#   ['suns'],
#   ['sunset', 'sunshine', 'sunburst', 'sunrise', 'sunburn']],
#  ['yellow', [], [], ['mellow', 'deepyellow', 'yell']],
#  ['clean', [], ['cleaner', 'cleanup', 'clean.'], []],
#  ['flat', [], [], ['flatui']],
#  ['sketch',
#   [],
#   ['sketchy', 'sketch.', 'sketchup', 'sketches'],
#   ['sketch-app', 'sketchfab', 'meinsketch', 'sketchnote']],
#  ['christmas',
#   [],
#   ['chritmas', 'christmass', 'chrismas'],
#   ['christmastree',
#    'christmascard',
#    'merrychristmas',
#    'christ',
#    '12daysofchristmas']],
#  ['christmastree',
#   ['chritmas', 'chrismas'],
#   [],
#   ['christams',
#    'bells',
#    'hannukah',
#    'stocking',
#    'snowball',
#    'hohoho',
#    'pornhub',
#    'jingle',
#    'christmascard',
#    'christmass',
#    'merrychristmas',
#    'elves',
#    'bauble',
#    'helper',
#    'snowmen',
#    'happyholidays',
#    'christmas',
#    '12daysofchristmas']],
#  ['gift', [], ['gifts'], []],
#  ['santaclaus',
#   ['santas'],
#   ['santacruz'],
#   ['christmastree',
#    'snowball',
#    'snowfall',
#    'rudolph',
#    'snoopy',
#    'stocking',
#    'sled',
#    'mittens',
#    'xmass',
#    'sledding',
#    'clause',
#    'hohoho',
#    'claus',
#    'sleigh',
#    'rudolf',
#    'snowglobe',
#    'snowman',
#    'santa',
#    'snowmen']],
#  ['snow',
#   [],
#   ['snowy'],
#   ['winter',
#    'snowmen',
#    'snowflake',
#    'snowing',
#    'snowglobe',
#    'snowman',
#    'snowfall']],
#  ['winter',
#   [],
#   [],
#   ['winterworkweek',
#    'snowmen',
#    'snowflake',
#    'snowing',
#    'snowman',
#    'snowfall',
#    'snow',
#    'snowy']],
#  ['insurance', [], [], ['entrance', 'insurtech']],
#  ['logodesign',
#   [],
#   ['logodesigner', 'logo-design', 'logodesigns'],
#   ['logodlc', 'logo-design66', 'logo.', 'branddesign', 'brand-design']],
#  ['yuro',
#   [],
#   [],
#   ['compound',
#    'isotipo',
#    'gradiente',
#    'madna',
#    'logo-concept',
#    'cajva',
#    'logoidentity',
#    'brand-identity',
#    'kostadin',
#    'connorbranding',
#    'brandmark',
#    'ghitea',
#    '3xter',
#    'brand-design',
#    'indentity',
#    'adaptivesoul']],
#  ['animals',
#   [],
#   ['animalshop', 'anima', 'animal'],
#   ['animallogo', 'animalssmoking']],
#  ['bear', [], ['bears'], ['polar', 'beargara', 'arctic']],
#  ['famous', [], [], []],
#  ['characterdesign',
#   ['charactern'],
#   ['character-design'],
#   ['character.',
#    '3dcharacter',
#    'childrensillustration',
#    'cutemonsters',
#    'digitalillustration',
#    'conceptdesign',
#    'dragonball',
#    'characterdevelopment',
#    'characteranimation',
#    'dbz',
#    'gorsky',
#    'charadesign',
#    'cutecharacters',
#    '?character',
#    'danielearcuri']],
#  ['danielearcuri',
#   [],
#   [],
#   ['12framesaday',
#    'daniele',
#    'mixedpartsbrief',
#    'animade',
#    'daniel',
#    'animdessin2',
#    'maginpanic',
#    'characterdevelopment',
#    '2dart',
#    'characteranimation',
#    'gorsky',
#    '100daysofmotion',
#    'cellanimation',
#    'artboard',
#    'animatecc',
#    '2dfx',
#    'animacion',
#    '2danimation',
#    'cartoonish']],
#  ['vector',
#   [],
#   ['vecto', 'vectors', 'vectored', 'vector.', 'vectores'],
#   ['vector-art', 'flatvector', 'flat-vector']],
#  ['candy',
#   [],
#   [],
#   ['cupcake',
#    'cane',
#    'choco',
#    'biscuit',
#    'candies',
#    'chocolate',
#    'canes',
#    'chocolates',
#    'chocolat',
#    'cookie',
#    'biscuits',
#    'candles',
#    'cacao']],
#  ['chat', [], ['chats'], ['chatbots', 'conversation', 'chatbot', 'chatting']],
#  ['claus',
#   [],
#   ['clause'],
#   ['cheer',
#    'navidad',
#    'sled',
#    'snowball',
#    'hohoho',
#    'santaclaus',
#    'reindeer',
#    'rudolf',
#    'sleigh',
#    'snowman',
#    'jingle',
#    'santas',
#    'snowglobe',
#    'elves',
#    'santa',
#    'snowmen',
#    'rudolph']],
#  ['download',
#   [],
#   ['downloads', 'downloading'],
#   ['freebies', 'downloadable', 'freedownload']],
#  ['emoji', [], ['emojis'], ['emoticon', 'emo', 'emoticons']],
#  ['free',
#   [],
#   [],
#   ['freepsd',
#    'freebies',
#    'freebie',
#    'psdfreebies',
#    'freeze',
#    'freedownload',
#    'freepik',
#    'freebie-friday']],
#  ['holiday',
#   [],
#   ['holidays'],
#   ['holidaycheck', 'romanholidays', 'holi', 'holidayseason', 'happyholidays']],
#  ['jingle',
#   [],
#   ['jiggle'],
#   ['christams',
#    'christmastree',
#    'cheer',
#    'stocking',
#    'natal',
#    'snowball',
#    'frosty',
#    'hohoho',
#    'pornhub',
#    'elves',
#    'santas',
#    'helper',
#    'gifmas',
#    'garland',
#    'bells']],
#  ['stickers',
#   [],
#   ['sticker'],
#   ['stickermule', 'stick', 'stickerpack', 'sticky']],
#  ['xmas',
#   [],
#   ['x-mas', 'xmass'],
#   ['navidad',
#    'claus',
#    'snowflake',
#    'presents',
#    'sleigh',
#    'reindeer',
#    'merrychristmas',
#    'merry',
#    'snowman',
#    'snowflakes',
#    'nutcracker',
#    'santa',
#    'rudolph']],
#  ['dribble',
#   [],
#   ['dirbbble',
#    'dribbbler',
#    'dribbblers',
#    'dribbble.',
#    'dribblers',
#    'dribbbble',
#    'dribbble',
#    'dribbble!'],
#   ['thankyou',
#    '1st',
#    'drafted',
#    'firstshot',
#    'hellodribbble',
#    'hellodribble',
#    'debuts',
#    'dribbbleinvite',
#    'debutshot',
#    'hello-dribbble',
#    'hey',
#    'debute',
#    'first-shot',
#    'frist']],
#  ['hotel', [], ['hotels'], []],
#  ['luxury', [], [], ['luxe', 'lux', 'luxurious']],
#  ['senses',
#   [],
#   ['sense', 'sensors'],
#   ['sm',
#    'eb',
#    'typeography',
#    'tight',
#    'heisler',
#    'itsvelestime',
#    'monotype',
#    'perfumes',
#    'monocolor',
#    'workmark',
#    'meraki',
#    'moroccan',
#    'pinus',
#    'wordplay',
#    'signet']],
#  ['simple', [], ['simply'], []],
#  ['spa', [], [], ['dermatology', 'pilates']],
#  ['stationery', [], ['stationary'], ['?stationary']],
#  ['clouds', [], ['cloudy', 'cloud'], ['aurora', '10clouds', 'dawn', 'bushes']],
#  ['deer', [], [], ['antlers', 'elk']],
#  ['illustratio',
#   [],
#   ['illustration??',
#    'illustration',
#    'illustratuin',
#    'illustratior',
#    'illustrate',
#    'illustration.'],
#   ['mean',
#    'plague',
#    'phantom',
#    'amphibian',
#    'horus',
#    'illustrationoftheday',
#    'mage',
#    'revenge',
#    'armour',
#    'assassin',
#    'armor',
#    'anubis',
#    'predator',
#    'lineillustration',
#    'bogul',
#    'scorpion',
#    'jkakaroto']],
#  ['little', [], [], []],
#  ['characters',
#   [],
#   ['charactern', 'character.', 'charachter', 'chatacters', 'character'],
#   ['3dcharacter', '?character', 'cutecharacters']],
#  ['park', [], ['parks'], []],
#  ['yoga', [], ['yogi'], []],
#  ['cool', [], [], []],
#  ['dribbble',
#   [],
#   ['dribbblers',
#    'dribbble.',
#    'dribbbble',
#    'dribbbler',
#    'dribble',
#    'dribbble!'],
#   ['debuts', 'dribbbleshot', 'hello-dribbble']],
#  ['interface',
#   [],
#   ['inteface', 'interfaces'],
#   ['interfacedesign',
#    'ui??nterface',
#    'useriinterface',
#    'userinterface',
#    'user-interface']],
#  ['planet',
#   [],
#   ['planes', 'planets'],
#   ['spaceship',
#    'planetary',
#    'spacecraft',
#    'meteor',
#    'outer',
#    'orbit',
#    'outerspace',
#    'spacesuit',
#    'saturn',
#    'pluto']],
#  ['clock', [], ['clocks'], ['clockwork', 'alarm']],
#  ['couch',
#   [],
#   [],
#   ['comfort',
#    'bathroom',
#    'bath',
#    'chair',
#    'bed',
#    'cozy',
#    'coupe',
#    'bedroom',
#    'livingroom',
#    'blanket']],
#  ['lamp', [], ['lamps'], []],
#  ['life', [], [], []],
#  ['living', [], [], ['livingroom']],
#  ['room', [], ['rooms'], ['livingroom']],
#  ['minimal.',
#   [],
#   ['minimalism', 'minimap', 'minimalis', 'minimalist', 'minimal'],
#   ['merriweather',
#    'lato',
#    'travell',
#    'minimal-monday',
#    'spacing',
#    'webite',
#    'pegs',
#    'minimalistic',
#    'minimum',
#    'telecommunication',
#    'lviv',
#    'lamps',
#    'shoply',
#    'mileage',
#    'stripe',
#    'piratebay',
#    'sportgirl']],
#  ['pillow', [], [], ['pills', 'pill', 'tissue', 'mellow', 'standing']],
#  ['sofa', [], [], ['shelf', 'livingroom']],
#  ['table',
#   [],
#   ['tables', 'tablets', 'tablet'],
#   ['tabletop', 'timetable', 'tableware', 'stable', 'portable']],
#  ['wall', [], ['walls'], ['wall-e']],
#  ['c', [], [], ['d', 'flux', 'l', 'm', 'cb', 'dn', 'b', 'ee', 'g', 'k', 'f']],
#  ['heart', [], ['hear', 'hearth', 'hearts'], ['heartbeat']],
#  ['l',
#   [],
#   [],
#   ['o',
#    'letterform',
#    'd',
#    'mase',
#    'c',
#    'ambigram',
#    'logo-exploration',
#    'g',
#    'u',
#    's',
#    '36days',
#    'tieatie',
#    'r',
#    'q',
#    'k',
#    'cr',
#    'f',
#    'logaze']],
#  ['pixel', [], ['pixels'], ['pixelart', 'pixel-art', 'pixelated']],
#  ['purple', [], [], []],
#  ['teal', [], [], ['turquoise']],
#  ['drawing',
#   [],
#   ['drawings', 'drawingart'],
#   ['linedrawing',
#    'digitaldrawing',
#    'figuredrawing',
#    'line-drawing',
#    'pencildrawing',
#    'handdrawing']],
#  ['graphics',
#   [],
#   ['graphics.'],
#   ['teddygraphics',
#    'graphicgraphic',
#    'nihal.graphics',
#    'krinographics',
#    'kommigraphics',
#    'zerographics',
#    'motion-graphics']],
#  ['illust',
#   [],
#   ['illus'],
#   ['illustrarion',
#    'illustratuin',
#    'illustrate',
#    'illustrasion',
#    'illustrasi',
#    'illustraor',
#    'illustraion']],
#  ['chip', [], ['chips', 'chi'], ['chipsa', 'drill', 'chief', 'chipmunk']],
#  ['gamble',
#   [],
#   [],
#   ['controllers',
#    'koshioshi',
#    'mmorpg',
#    'nier',
#    'gaz',
#    'roulette',
#    'keno',
#    'barbarian',
#    'fnatic',
#    'gamers',
#    'cardgame',
#    'gamer',
#    'gambling',
#    'gamepad',
#    'gameloft',
#    'battlegrounds',
#    'enemy',
#    'gameui',
#    'tabletop',
#    'gambino',
#    'mortal',
#    'amblem']],
#  ['hellodribbble',
#   [],
#   ['hellodribble', 'hello-dribbble'],
#   ['dirbbble',
#    'dribbbler',
#    '1st',
#    'illustrationgraphic',
#    'firstshoot',
#    'designthursday',
#    'firstshot',
#    'debutshot',
#    'hola',
#    'hey',
#    'dribbble.',
#    'dribbbble',
#    'dribblers',
#    'debute',
#    'dribbbleshot',
#    'dribbble',
#    'dribbble!',
#    'first-shot',
#    'frist']],
#  ['animal',
#   [],
#   ['animals', 'anima'],
#   ['animalshop', 'animallogo', 'animalssmoking']],
#  ['leo',
#   [],
#   ['leon'],
#   ['sagittarius',
#    'bengal',
#    'lonzo',
#    'gods',
#    'tlingit',
#    'wand',
#    'larry',
#    'headband',
#    'sec',
#    'savage',
#    'gorgon',
#    'elizabeth',
#    'kim',
#    'leg',
#    'odin',
#    'officer']],
#  ['lion', [], [], []],
#  ['head', [], ['heads'], ['headache', 'ahead']],
#  ['golden', [], [], ['goldenratio', 'golden-ratio']],
#  ['horse',
#   [],
#   ['horses'],
#   ['horseshoe', 'horn', 'seahorse', 'horus', 'horseman']],
#  ['gold', [], [], []],
#  ['foil', [], [], ['metallic', 'letterpress', 'embossed', 'deboss', 'emboss']],
#  ['packaging',
#   [],
#   ['packagine', 'packing'],
#   ['packages', 'package', 'packagingdesign']],
#  ['label', [], ['labels'], ['labelmaker', 'labeling']],
#  ['feminine', [], [], ['gemini', 'chic', 'delicate']],
#  ['handmade',
#   [],
#   ['hand-made'],
#   ['handmadetype',
#    'hand-type',
#    'hand-written',
#    'handdone',
#    'handcraft',
#    'handmadefont',
#    'handcrafted']],
#  ['jewelry', [], ['jeweler', 'jewels', 'jewellery', 'jewel'], ['jew']],
#  ['minimalist',
#   [],
#   ['minimalism', 'minimalis', 'minimalistic', 'minimal', 'minimal.'],
#   ['?minimal', 'minimallogo', 'minimum']],
#  ['symbol', [], [], ['symbolmark', 'symbolism', 'symbology']],
#  ['car', [], ['cars'], []],
#  ['city', [], [], ['cityscape', 'citybee']],
#  ['house',
#   [],
#   ['houses'],
#   ['grabhouse',
#    'housework',
#    'in-house',
#    'guesthouse',
#    'houseplant',
#    'household']],
#  ['people', [], ['peoples'], []],
#  ['plane',
#   [],
#   ['planes'],
#   ['aeroplane', 'airplanes', 'airplane', 'paperplane', 'biplane']],
#  ['ship', [], ['ships'], []],
#  ['transportation',
#   [],
#   [],
#   ['vehicles',
#    'suv',
#    'vehicle',
#    'navigate',
#    'taxi',
#    'parking',
#    'public',
#    'tram',
#    'transport',
#    'trucks',
#    'logistics',
#    'pickup',
#    'passenger',
#    'railway',
#    'transit',
#    'trucking']],
#  ['3d', [], [], ['b3d']],
#  ['morocco',
#   [],
#   ['moroccan'],
#   ['te',
#    'mojo',
#    'mor8',
#    'onecolor',
#    'gondola',
#    'senses',
#    'alcantara',
#    'torii',
#    'bulding',
#    'morris',
#    'qatar',
#    'palmtree',
#    'sanfrancisco',
#    't2',
#    'terrain',
#    'sundown',
#    'moslem']],
#  ['realistic', [], [], ['photorealistic', 'photorealism', 'surrealistic']],
#  ['tea', [], [], ['latte']],
#  ['data',
#   [],
#   [],
#   ['bigdata',
#    'datavis',
#    'datacenter',
#    'dataviz',
#    'graphs',
#    'datavisualization',
#    'analytics',
#    'database',
#    'data-viz']],
#  ['extreme', [], [], ['xtreme', 'mtb']],
#  ['gopro',
#   [],
#   [],
#   ['lowprofile',
#    'leica',
#    'detection',
#    'breezy',
#    'adjust',
#    'material-design',
#    'capture',
#    'authoring',
#    'sncf',
#    'carsharing',
#    'accelerometer',
#    'carpooling',
#    'eleken',
#    'favourites',
#    'yandex']],
#  ['map', [], ['maps'], []],
#  ['user', [], [], ['usability', 'user-experience', 'experience', 'userflow']],
#  ['experience',
#   [],
#   ['experiences', 'eksperience', 'experince'],
#   ['user', 'userexperience', 'experiential', 'user-experience']],
#  ['key', [], [], []],
#  ['features',
#   [],
#   ['feature', 'featured'],
#   ['benefits',
#    'inquiry',
#    'affiliate',
#    'corporation',
#    'clients',
#    'enterprise',
#    'customers',
#    'careers',
#    'markets',
#    'constructor',
#    'ppc',
#    'darren',
#    'conversion',
#    'indianic',
#    'landingspage']],
#  ['stroke', [], ['strokes'], []],
#  ['cards', [], ['card.', 'card'], ['flashcards', '99cards']],
#  ['dark', [], [], ['darkblue', 'darkui', 'darkmode']],
#  ['applepencil',
#   [],
#   [],
#   ['mariashishcova',
#    'raster',
#    'procreateapp',
#    'dragonballz',
#    'ipad-pro',
#    'pencildrawing',
#    'pencil',
#    'rendered',
#    'handdrawing',
#    'beziers',
#    'brushpen',
#    'penandink',
#    'portraitartist',
#    'lettrage',
#    'brushcript',
#    'pencils',
#    'ipadpro',
#    'toodles',
#    'astropad']],
#  ['campaign', [], ['campaigns'], []],
#  ['ipadpro',
#   [],
#   ['ipad-pro'],
#   ['selfportrait',
#    'mariashishcova',
#    'cintiq',
#    'raster',
#    'procreate',
#    'procreateapp',
#    'applepencil',
#    'adobesketch',
#    'astropad',
#    'penandink',
#    'pencildrawing',
#    'portraitartist',
#    'lettrage',
#    'brushcript',
#    'ipad']],
#  ['vectorillustration',
#   [],
#   ['vector-illustration'],
#   ['tommyartdesign',
#    'studioghibli',
#    'i?llustration',
#    'llustration',
#    'iconart',
#    'illustrationoftheday',
#    'typographyart',
#    'stickerdesign',
#    'mrugaillustration',
#    'vectorportrait',
#    'shafix',
#    'vectordesign',
#    'vectoricons',
#    'ghibli',
#    'lineillustration',
#    'vectorart',
#    'graphicart',
#    'dribbbleshot',
#    'flatillustration',
#    '?illustration']],
#  ['artist',
#   [],
#   ['artistic', 'artists'],
#   ['artistique', 'indianartist', 'artistsix']],
#  ['designer',
#   [],
#   ['designers', 'design.'],
#   ['radesigner',
#    'freelancerdesigner',
#    'designer??rt',
#    'jondesigner',
#    'esigner',
#    'ui-designer']],
#  ['pencil', [], ['pencils'], ['applepencil', 'pen', 'pencildrawing']],
#  ['sketchbook',
#   [],
#   ['sketchnote'],
#   ['markerart',
#    'sketchy',
#    'sketched',
#    'moleskine',
#    'sketchfab',
#    'sketch.',
#    'sketchup',
#    'sketching',
#    'sketches']],
#  ['sketching',
#   [],
#   [],
#   ['sketchbook',
#    'sketch-app',
#    'sketchy',
#    'sketched',
#    'moleskine',
#    'sketchfab',
#    'sketch.',
#    'sketchup',
#    'sketches']],
#  ['lynx',
#   [],
#   [],
#   ['lacrosse',
#    'tulsa',
#    'idaho',
#    'mv',
#    'colt',
#    'heraldic',
#    'kk',
#    'roundel',
#    'co.',
#    'monogramm',
#    'mh',
#    'jk',
#    'mk',
#    'pegasus',
#    'grafik',
#    'eb',
#    'smart-logo',
#    'p?o',
#    'griffin']],
#  ['travel',
#   [],
#   ['travell', 'travelog', 'traveler', 'travels'],
#   ['traveling', 'traveller', 'travelling', 'trip', 'travelers']],
#  ['draft',
#   [],
#   ['drafted', 'drafts'],
#   ['drafting',
#    'dribbblers',
#    'dribbbleinvitation',
#    '2xinvite',
#    'giveway',
#    'winners',
#    'giveaways',
#    '2x',
#    'dribbbler',
#    'admit',
#    'dribbbleinvites',
#    'dribbbleinvite',
#    'giveaway']],
#  ['giveaway',
#   [],
#   ['giveway', 'giveaways'],
#   ['drafting',
#    'dribbbleinvitation',
#    '2xinvite',
#    'invite',
#    'winners',
#    'invitations',
#    'invites',
#    '2x',
#    'drafted',
#    'admit',
#    'dribbbleinvites',
#    'away',
#    'dribbbleinvite',
#    'draft',
#    'prospects']],
#  ['invitation',
#   [],
#   ['invitations'],
#   ['dribbbleinvitation',
#    '2xinvite',
#    'giveway',
#    'invite',
#    'invites',
#    'invited',
#    'levitation']],
#  ['invite',
#   [],
#   ['invites', 'invited'],
#   ['dribbbleinvitation',
#    '2xinvite',
#    'giveway',
#    'dribbleinvite',
#    'invitations',
#    'drafted',
#    'invitation',
#    'dribbbleinvite',
#    'dribbbleinvites',
#    'prospects',
#    'giveaway']],
#  ['player', [], ['players'], ['videoplayer', 'musicplayer']],
#  ['portfolio', [], ['portofolio'], ['folio']],
#  ['rider',
#   [],
#   ['raider', 'ride', 'riders'],
#   ['lowrider', 'riding', 'racer', 'motorbike', 'motorcyclist']],
#  ['hiking',
#   [],
#   [],
#   ['outside',
#    'hiker',
#    'hike',
#    'kayaking',
#    'hammock',
#    'outdoors',
#    'biking',
#    'climbing',
#    'camping',
#    'climb',
#    'camp',
#    'expedition',
#    'backpacking']],
#  ['mascot', [], ['mascotte', 'mascots'], ['mascotlogo']],
#  ['monster',
#   [],
#   ['monstercat', 'monsters.', 'monstera', 'monsters'],
#   ['cutemonsters']],
#  ['unicorn',
#   [],
#   ['unicorns'],
#   ['walrus',
#    'silly',
#    'whimsical',
#    'teddy',
#    'sadness',
#    'slime',
#    'pony',
#    'tongue',
#    'wink']],
#  ['doodle', [], ['doodles'], ['doodling']],
#  ['skateboard',
#   ['skater'],
#   ['skateboarding', 'skateboarder', 'skateboards'],
#   ['wakeboard', 'skatedeck', 'skate', 'skates', 'longboard']],
#  ['skateboarder',
#   ['skater'],
#   ['skateboarding', 'skateboard', 'skateboards'],
#   ['skateshop',
#    'skatedeck',
#    'skate',
#    'surrealist',
#    'puppets',
#    'yoyo',
#    'skates',
#    'longboard',
#    'nickelodeon',
#    'sk8',
#    'spongebob',
#    'tvpaint',
#    'skeletons',
#    'werewolf',
#    'squarepants']],
#  ['skater',
#   [],
#   ['skate', 'skates'],
#   ['skateboard',
#    'skateboarding',
#    'skating',
#    'skateboarder',
#    'walkcycle',
#    'rubberhose',
#    'skatedeck',
#    'trick',
#    'scared',
#    'tvpaint',
#    'longboard',
#    'sk8',
#    'spongebob',
#    'nickelodeon',
#    'robomg',
#    'skateboards',
#    'skipping',
#    'lavency']],
#  ['skating',
#   [],
#   [],
#   ['skateboarder',
#    'snowflake',
#    'skater',
#    'skatedeck',
#    'santaclaus',
#    'rink',
#    'sk8']],
#  ['after',
#   [],
#   [],
#   ['afx',
#    '?after-effects',
#    'afteeffects',
#    'after-effects',
#    'afternoon',
#    'after-effecs',
#    'aftereffect',
#    'aftereffects']],
#  ['effects',
#   [],
#   ['effect'],
#   ['?after-effects',
#    'after-effects',
#    'afteeffects',
#    'after-effecs',
#    'aftereffect',
#    'affects',
#    'aftereffects']],
#  ['and', [], [], []],
#  ['cute', [], [], []],
#  ['dance', [], ['dancer', 'dancers'], ['dancing', 'breakdance']],
#  ['dancing', [], [], ['dance', 'fencing', 'papa', 'drummer']],
#  ['rubberhose',
#   [],
#   [],
#   ['toonboom',
#    'mixedpartsbrief',
#    '?duik',
#    'rigging',
#    'renaud',
#    'walkcycle',
#    'squash',
#    'duik',
#    'rig',
#    'mixedparts',
#    'runcycle',
#    'rubber',
#    'pingpong',
#    'rotoscoping',
#    'jambo-work',
#    'hose',
#    'lavency',
#    'rigg']],
#  ['apple', [], ['apply', 'appletv', 'apples'], ['applewatch', 'app.']],
#  ['pay',
#   [],
#   [],
#   ['expenses',
#    'transactions',
#    'payment',
#    'cashback',
#    'debit',
#    'payments',
#    'p2p',
#    'paypal',
#    'paywall',
#    'transaction',
#    'paycase',
#    'visa',
#    'paytm',
#    'mastercard',
#    'keypad',
#    'transfer',
#    'offers',
#    'income']],
#  ['camera', [], ['cameras'], []],
#  ['checkout',
#   [],
#   [],
#   ['creditcard',
#    'customize',
#    'credits',
#    'cart',
#    '100daysofui',
#    'debit',
#    'mastercard',
#    'credit',
#    'check-in',
#    'creditcardcheckout',
#    '033',
#    'confirmation',
#    'checkin',
#    '002',
#    'dailyui002',
#    '012']],
#  ['fan', [], [], ['disney-with-us']],
#  ['gallery', [], [], ['photogallery', 'galleries']],
#  ['permissions',
#   [],
#   ['permission'],
#   ['suggest',
#    'authoring',
#    'reminders',
#    'missions',
#    'vezina',
#    'managment',
#    'submission',
#    'views',
#    'options',
#    'questions',
#    'popover',
#    'suggestions',
#    'sidemenu',
#    'integrations',
#    'versions',
#    'tabbar',
#    'toolbar',
#    'translator',
#    'stages',
#    'contextual',
#    'timesheet']],
#  ['photo',
#   [],
#   ['photos'],
#   ['photocomp',
#    'photobash',
#    'photogallery',
#    'photocopy',
#    'photograpgy',
#    'photomontage',
#    'photosop']],
#  ['selection',
#   [],
#   ['section'],
#   ['topic',
#    'satisfaction',
#    'stepper',
#    'preferences',
#    'protopie',
#    'microinteraction',
#    'rating',
#    'iphones',
#    'prd',
#    'zoom',
#    'select',
#    'translate',
#    'election',
#    'microanimation',
#    'walkthrough',
#    'submit',
#    'tabbar']],
#  ['scrolling',
#   [],
#   [],
#   ['paralax',
#    'mariuszkunc',
#    'rolling',
#    'scroll',
#    'ui-ux',
#    'tilda',
#    'ui8',
#    'pagination',
#    'webflow',
#    'redkiwi',
#    'webdev',
#    'transitions',
#    'selling',
#    'viewport',
#    'ux.',
#    'fullwidth',
#    'rollover',
#    'sliding',
#    'zipl']],
#  ['brochure',
#   [],
#   ['brochures'],
#   ['catalog',
#    'bifold',
#    'indesign',
#    'tri-fold',
#    'f1digitals',
#    'booklet',
#    'a4',
#    'a5',
#    'bi-fold']],
#  ['building',
#   [],
#   ['buildings', 'bulding'],
#   ['build', 'built', 'bodybuilding']],
#  ['card', [], ['card.', 'cards'], ['idcard', 'ecard']],
#  ['company', [], [], ['companies', 'companion', 'companylogo']],
#  ['profile', [], ['profiles', 'profil'], ['lowprofile', 'userprofile']],
#  ['construction',
#   [],
#   ['constructions', 'construct', 'constructor'],
#   ['instruction',
#    'deconstructed',
#    'underconstruction',
#    'destruction',
#    'constructivism']],
#  ['envelope', [], ['envelopes', 'envelop'], []],
#  ['flyer', [], ['flyers'], []],
#  ['marketing', [], [], ['digitalmarketing']],
#  ['debut',
#   [],
#   ['debuts', 'debute'],
#   ['hello',
#    'firstshoot',
#    'firstshot',
#    '1st',
#    'hellodribbble',
#    'debutshot',
#    'first-shot',
#    'first']],
#  ['first',
#   [],
#   [],
#   ['shot',
#    'debuts',
#    'hellodribble',
#    'hello',
#    'first-shot',
#    'debut',
#    'firstshot',
#    '1st',
#    'hellodribbble',
#    'illustrationgraphic',
#    'debutshot',
#    'firstshoot']],
#  ['shot',
#   [],
#   ['shots'],
#   ['hellodribble',
#    'hello',
#    'firstshoot',
#    'firstshot',
#    'hellodribbble',
#    'debutshot',
#    'first-shot',
#    'first']],
#  ['hello',
#   [],
#   [],
#   ['shot',
#    'debuts',
#    'hellodribble',
#    'thanks',
#    'firstshoot',
#    'debut',
#    'firstshot',
#    '1st',
#    'hellodribbble',
#    'debute',
#    'illustrationgraphic',
#    'hi',
#    'debutshot',
#    'first-shot',
#    'first',
#    'hello-dribbble']],
#  ['space',
#   [],
#   ['spacex', 'spaced', 'spaces'],
#   ['spaceship', 'spacetime', 'outerspace', 'spacesuit', 'spaceman']],
#  ['architecture',
#   [],
#   ['architects', 'architect', 'architectural'],
# ...
#    'swimmer',
#    'swim',
#    'seaweed',
#    'starfish',
#    'swimming',
#    'sailboat',
#    'water',
#    'reef',
#    'seagulls',
#    'scuba',
#    'submarine']],
#  ['hump',
#   [],
#   [],
#   ['hug',
#    'humor',
#    'festivus',
#    'humorous',
#    '69',
#    'bobsled',
#    'phil',
#    'iwd2018',
#    'v-day',
#    'galentines',
#    'pugs',
#    'grumpy',
#    'asleep',
#    'vday',
#    '8th',
#    'hugs',
#    'leslie',
#    'humour',
#    'heytvm',
#    'forget',
#    'unlucky',
#    'slap',
#    'knope']],
#  ['day', [], [], ['day4', 'vday', 'day3', 'day2', 'v-day', 'day5']],
#  ['wednesday',
#   [],
#   [],
#   ['thursday',
#    'slime',
#    'womensday',
#    'tombstone',
#    'saturday',
#    'v-day',
#    'teardrop',
#    'doomsday',
#    'squiggle',
#    'vday',
#    'tear',
#    'tuesday',
#    'revenge',
#    'tango',
#    'tame',
#    'nirvana',
#    'sleepy',
#    'iwd2018聽womensday',
#    'witchy',
#    'impala',
#    'wink',
#    'vortex',
#    'shakespeare']],
#  ['bees',
#   [],
#   ['beet', 'bee', 'beef', 'beep'],
#   ['bumble',
#    'bandana',
#    'honey',
#    'beetles',
#    'beethoven',
#    'eyelashes',
#    'berries',
#    'columbine',
#    'exotic',
#    'berry',
#    'daisy',
#    'blossom',
#    'beehive',
#    'flor',
#    'fauna',
#    'honeycomb',
#    'bumblebee',
#    'beetle']],
#  ['blossom',
#   [],
#   ['blossoms'],
#   ['greens',
#    'aquarelle',
#    'botanicals',
#    'ceramics',
#    'butterflies',
#    'evergreen',
#    'blueberries',
#    'hanovi',
#    'berries',
#    'columbine',
#    'dragonfly',
#    'peony',
#    'eucalyptus',
#    'exotic',
#    'daisy',
#    'garlic',
#    'caramel',
#    'cherries',
#    'flor',
#    'fauna',
#    'hibiscus']],
#  ['bugs',
#   [],
#   ['bug'],
#   ['critter',
#    'butterflies',
#    'buddy',
#    'bedbug',
#    'daisy',
#    'beetles',
#    'insects',
#    'enchanted',
#    'flora',
#    'beet',
#    'charcoal',
#    'bonifacio',
#    'ethnic',
#    'comissioned',
#    'ghosts',
#    'beetle',
#    'fauna',
#    'comission',
#    'babies']],
#  ['floral',
#   [],
#   ['florals', 'flora'],
#   ['bouquet',
#    'botanical',
#    'flor',
#    'floristry',
#    'flower',
#    'florist',
#    'flowers']],
#  ['flower',
#   ['flor'],
#   ['flowers'],
#   ['sunflower', 'flowerpot', 'floral', 'lower', 'flora', 'wildflower']],
#  ['skeleton', [], ['skeletons'], ['skull', 'rockabilly', 'reaper', 'skulls']],
#  ['skull', [], ['skulls'], ['skeleton']],
#  ['suit', [], [], ['tie']],
#  ['behance', [], [], ['chance']],
#  ['depression',
#   [],
#   [],
#   ['discussion',
#    'anxiety',
#    'mommy',
#    'expressions',
#    'confidence',
#    'curl',
#    'braid',
#    'beehive',
#    'blond',
#    'expressionism',
#    'creep',
#    'cigarette',
#    'expression',
#    'babes',
#    'gel',
#    'impression',
#    'bones',
#    'drugs']],
#  ['pro', [], [], []],
#  ['gaming',
#   [],
#   ['gambino'],
#   ['gamer',
#    'wargaming',
#    'gameui',
#    'retrogaming',
#    'gamepad',
#    'gamers',
#    'esports',
#    'games']],
#  ['sad',
#   [],
#   [],
#   ['sleepy', 'sadness', 'reaction', 'sadhu', 'lust', 'tired', 'laugh']],
#  ['blog', [], ['blogs'], ['blogging']],
#  ['landingpage',
#   [],
#   ['loadingpage', 'landing-page', 'landingspage'],
#   ['landing', 'onepage', 'loginpage', 'webpage', '404page']],
#  ['traveling',
#   [],
#   ['travelog', 'travelling'],
#   ['vacations',
#    'trips',
#    'travelogue',
#    'voyage',
#    'travell',
#    'tours',
#    'tourist',
#    'suitcase',
#    'traveller',
#    'tourism',
#    'wander',
#    'tripadvisor',
#    'traveler',
#    'urlaub',
#    'trip',
#    'travels',
#    'travelers']],
#  ['snake', [], ['snakes', 'snakn'], ['reptile']],
#  ['tattoo', [], ['tatoo', 'tattoos', 'tatto'], ['tattoomunich']],
#  ['contrast', [], ['contract'], ['contempoary', 'concrete']],
#  ['galaxy', [], [], ['gala']],
#  ['red', [], [], []],
#  ['s8',
#   [],
#   [],
#   ['teddygraphics',
#    'uwp',
#    'theblueprint',
#    'otp',
#    'iphone6',
#    'ihmahmoodi',
#    'mahmoodi',
#    'iphone8',
#    'translator',
#    's9',
#    'note8',
#    'samsung',
#    'xl',
#    'oneplus',
#    'organize',
#    'recorder',
#    'dth',
#    'perfumer',
#    'uplabs',
#    'madewithadobexd']],
#  ['samsung',
#   [],
#   [],
#   ['s8',
#    'teddygraphics',
#    's9',
#    'note8',
#    'oneplus',
#    'huawei',
#    'xl',
#    'high-resolution',
#    'a7']],
#  ['box', [], ['boxe'], []],
#  ['comics',
#   [],
#   ['comic'],
#   ['blackpanther',
#    'deadpool',
#    'dccomics',
#    'ragnarok',
#    'inks',
#    'batman',
#    'avengers',
#    'comida',
#    'comicbook',
#    'hulk',
#    'loki',
#    'ironman',
#    'cartooning',
#    'omics']],
#  ['strip',
#   [],
#   ['strips', 'stripe', 'striped', 'stripes'],
#   ['tony',
#    'shuri',
#    'madonna',
#    'strut',
#    'excelsior',
#    'loki',
#    'murphy',
#    'kapowl',
#    'calvin',
#    'psycho',
#    'strike',
#    'struggle',
#    'pow',
#    'parker',
#    'sivadigitalart',
#    'ulysses',
#    'ragnarok']],
#  ['lettermark',
#   [],
#   ['letterform'],
#   ['logo.',
#    'goldenratio',
#    'letter',
#    'logo-experimentation',
#    'initials',
#    'letterforms',
#    'h',
#    'r',
#    'k',
#    'l',
#    'logo-concept',
#    'brand-identity',
#    'brandmark',
#    'g',
#    'owen',
#    'logo-exploration',
#    'gridding',
#    'modernist',
#    'tieatie',
#    'logaze']],
#  ['process', [], ['processor', 'processing'], []],
#  ['z', [], [], ['y']],
#  ['funny', [], [], ['funnyart', 'punny']],
#  ['milkshake',
#   [],
#   [],
#   ['oven',
#    'eggplant',
#    'nitrogen',
#    'mistake',
#    'muffin',
#    'redruby',
#    'lip',
#    'juicy',
#    'sake',
#    'hazelnut',
#    'icing',
#    'cheesy',
#    'macarons',
#    'ketchup',
#    'cinnamon',
#    'doughnuts',
#    'milky',
#    'onigiri',
#    'shake',
#    'fhc30',
#    'milk',
#    'marshmallow',
#    'macaron']],
#  ['motif',
#   [],
#   [],
#   ['weave',
#    'painterly',
#    'surfacepattern',
#    'repeating',
#    'mantra',
#    'textiles',
#    'marbled',
#    'petals',
#    'handpainted',
#    'seamlesspattern',
#    'moroccan',
#    'peonies',
#    'lace',
#    'hibiscus',
#    'multicolored']],
#  ['crm',
#   [],
#   [],
#   ['claims',
#    'benefits',
#    'dasboard',
#    'authentication',
#    'cms',
#    'reports',
#    'corporation',
#    'clients',
#    'api',
#    'admin',
#    'apply',
#    'b2b',
#    'backoffice',
#    'landlord',
#    'sap',
#    'backend',
#    'analytic',
#    'erp',
#    'sugarcrm',
#    'audit']],
#  ['exit',
#   [],
#   [],
#   ['greed',
#    'exam',
#    'ants',
#    'coworker',
#    'conflict',
#    'clickbait',
#    'flats',
#    'generate',
#    'backup',
#    'lagos',
#    'backpacker',
#    'browsing',
#    'communities',
#    'fulfillment',
#    'ex',
#    'expanse',
#    'btn',
#    'analyst',
#    'authors',
#    'ide']],
#  ['fonts',
#   [],
#   ['font'],
#   ['fontbyme', 'headfonts', 'fontself', 'fontface', 'fontfabric']],
#  ['modal',
#   [],
#   ['modals'],
#   ['dialog',
#    'register',
#    'popup',
#    'fields',
#    'pop-up',
#    'input',
#    'forgot',
#    'password',
#    'registration',
#    'trial',
#    'hint',
#    'sign-up',
#    'submit',
#    'subscribe',
#    'username']],
#  ['scribble',
#   [],
#   ['scrabble'],
#   ['squiggle',
#    'markerart',
#    'micron',
#    'strokes',
#    'prisma',
#    'stippling',
#    'crayon',
#    'sharpener',
#    'toodles',
#    'thoughts',
#    'wobble',
#    'splatter',
#    'pebble',
#    'splat',
#    'scrib',
#    'melancholy',
#    'stipple',
#    'textured',
#    'hellodribble']],
#  ['country',
#   [],
#   ['county'],
#   ['backcountry',
#    'columbus',
#    'cambridge',
#    'columbia',
#    'countryside',
#    'countries',
#    'britain']],
#  ['overlay', [], ['overlap', 'overlays'], ['overlapping']],
#  ['transparency',
#   [],
#   ['transparent', 'translucency'],
#   ['scanner',
#    'translucent',
#    'trans',
#    'radial',
#    'percent',
#    'transferi',
#    'penrose',
#    'ss',
#    'opacity',
#    'stripe']],
#  ['triangles',
#   ['tangle'],
#   ['triangle'],
#   ['squares',
#    'sphere',
#    'impossible',
#    'prism',
#    'rectangle',
#    'zentangle',
#    'symmetry',
#    'polygonal',
#    'polygon',
#    'threes',
#    'repetition',
#    'fractal',
#    'offgrid',
#    'penrose',
#    'twist',
#    'striped',
#    'op',
#    'rectangles',
#    'riangle']],
#  ['nyc', [], [], ['reno', 'york', 'bklyn', 'nyt', 'newyork']],
#  ['pen', [], ['pens'], ['pencil']],
#  ['ink', [], [], ['inktober2017', 'inktober']],
#  ['steven',
#   [],
#   ['steve'],
#   ['linocut',
#    'ratchet',
#    'woodcuts',
#    'stevenson',
#    'kepler',
#    'scratch',
#    'scratchboard',
#    'noble']],
#  ['fox', [], ['foxy'], []],
#  ['personage',
#   [],
#   ['personal', 'personagem', 'personas', 'persona', 'personaje'],
#   ['caracter',
#    'onga',
#    'amphibian',
#    'personalised',
#    'shaman',
#    'personalized',
#    'gorgon',
#    'barbarians',
#    'mrugaillustration',
#    'nessie',
#    'person',
#    'triceratops',
#    'guts',
#    'toad',
#    'pony',
#    'jkakaroto',
#    'gato',
#    'ax']],
#  ['bitcoin',
#   ['btc'],
#   [],
#   ['cryptocurrency',
#    'etherium',
#    'ico',
#    'coin',
#    'cryptocoin',
#    'ethereum',
#    'crypto',
#    'blockchain',
#    'currency',
#    'eth',
#    'cryptocurrencies',
#    'cryptocurrenty',
#    'cryptocurency',
#    'crypocurrency',
#    'altcoin',
#    'exchange',
#    'ether']],
#  ['coins',
#   [],
#   ['coin'],
#   ['dogecoin',
#    'cryptokitties',
#    'cryptocoin',
#    'bytecoin',
#    'btc',
#    'digger',
#    'bonus',
#    'ether',
#    'dollar',
#    'cryptocurrenty',
#    'altcoins',
#    'coinbase']],
#  ['etherium',
#   [],
#   ['etherum', 'ethereum'],
#   ['bp',
#    'ethereal',
#    'bytecoin',
#    'cryptocoin',
#    'blockstack',
#    'litecoin',
#    'cryptocurency',
#    'eth',
#    'cryptocurrencies',
#    'paycase',
#    'currencies',
#    'distributed',
#    'gulden',
#    'monero',
#    'tokens',
#    'altcoin',
#    'ether',
#    'coinbase']],
#  ['recycling',
#   [],
#   [],
#   ['cycling',
#    'recycle',
#    'pathway',
#    'waterdrop',
#    'tiempos',
#    'talks',
#    'pubs',
#    'thunderbird',
#    'wc',
#    'volvo',
#    'velvet',
#    'prop',
#    'simplified',
#    'sixth',
#    'tecnology',
#    'waterloo',
#    'rehabilitation']],
#  ['airlines',
#   [],
#   ['airline', 'airliner', 'airplanes', 'aerolineas'],
#   ['airpods',
#    'argentinas',
#    'airport',
#    'departure',
#    'check-in',
#    'geolocation',
#    'airplane',
#    'bookings',
#    'airbus',
#    'baggage',
#    'boeing',
#    'airbn',
#    'flights',
#    'checkin',
#    'airways',
#    'directions']],
#  ['argentinas',
#   [],
#   ['argentina'],
#   ['autocomplete',
#    'factor',
#    'changes',
#    'analyse',
#    'check-in',
#    'ongoing',
#    'amenities',
#    'realtime',
#    'condition',
#    'algolia',
#    'checkin',
#    'n26',
#    'aerolineas',
#    'airways',
#    'biometrics']],
#  ['layer', [], ['layers'], ['layerlab', 'flayer']],
#  ['menu', [], ['menus'], ['menubar']],
#  ['patagonia',
#   [],
#   [],
#   ['adirondacks',
#    'santiago',
#    'mountaineering',
#    'tanzania',
#    'mt',
#    'vibrations',
#    'kayaking',
#    'yosemite',
#    'denali',
#    'nps',
#    'sugarlands',
#    'expedition',
#    'kayak',
#    'teton',
#    'everest',
#    'screamin',
#    'begonia',
#    'estonia',
#    'mt.']],
#  ['cinema', [], [], ['cinema4d', '4d', 'cinemagraph', 'cinematic']],
#  ['4d',
#   [],
#   [],
#   ['c4d',
#    'octane',
#    'camilociprian',
#    'cinema4d',
#    'cinema',
#    'maxonc4d',
#    'coronarender',
#    '3dtype',
#    'cgi',
#    'maxon',
#    'eyedesyn',
#    'cinematic']],
#  ['strawberry',
#   [],
#   ['strawberries'],
#   ['lemons',
#    'vegetable',
#    'yum',
#    'pineapple',
#    'milkshake',
#    'lemon',
#    'watermelon',
#    'yummy',
#    'onion',
#    'mustard',
#    'nuts',
#    'peanut',
#    'juicy',
#    'pear',
#    'lime',
#    'veggie',
#    'raspberry',
#    'tasty']],
#  ['sweet', [], ['sweets'], ['sprinkles', 'sugar', 'sweepstakes']],
#  ['potion',
#   [],
#   ['potions'],
#   ['poison',
#    'slug',
#    'tornado',
#    'ramotion',
#    'nuclear',
#    'lotion',
#    'shaman',
#    'saber',
#    'venom',
#    'x-ray',
#    'spell',
#    'satan']],
#  ['freepsd',
#   [],
#   ['freepik'],
#   ['psdfreebies',
#    'resumes',
#    'mock-ups',
#    'freebie-friday',
#    'freemockup',
#    'roll-up',
#    'baner',
#    'free',
#    'dipixio',
#    'scenecreator',
#    'freeze',
#    'miscellaneous',
#    'high-resolution',
#    'freebies',
#    'signboard',
#    'mysuperproject',
#    'freebie',
#    'newpaper',
#    'hardcover',
#    'ockup',
#    'freedownload']],
#  ['coworking',
#   [],
#   ['co-working'],
#   ['coworker', 'woodworking', 'cowork', 'working']],
#  ['london', [], [], []],
#  ['parallax', [], ['paralax'], ['pageload', 'scrolling', 'webflow']],
#  ['prototype', [], ['prototypes', 'prototyping'], ['framerjs', 'protopie']],
#  ['uk', [], [], []],
#  ['bold', [], [], []],
#  ['bright', [], ['brights'], ['brightness']],
#  ['honduras',
#   [],
#   [],
#   ['kombucha',
#    'co.',
#    'brewing',
#    'gekkeikan',
#    'hopped',
#    'labeldesign',
#    'craftbeer',
#    'hongkong',
#    'niechanowo',
#    'barba',
#    'growler',
#    'laika',
#    'cerveja',
#    'braunfels',
#    'brewhouse',
#    'cans',
#    'fmcg',
#    'creola',
#    'empyrean',
#    'colt',
#    'barrels',
#    'homebrew']],
#  ['preview',
#   [],
#   [],
#   ['scrolling',
#    'professionals',
#    'ui-ux',
#    'cases',
#    'pagination',
#    'redkiwi',
#    'rollover',
#    'review',
#    'headers',
#    'sanserif',
#    'mondrianism',
#    'reviews']],
#  ['wip', [], [], []],
#  ['capermint',
#   [],
#   [],
#   ['fora',
#    'cosmicode',
#    'ergonomics',
#    'delightful',
#    'apply',
#    'monday.com',
#    'agence',
#    'bala',
#    'brainstorming',
#    'anand',
#    'briefbox',
#    'accelerometer',
#    'adaptation',
#    'uw-stout',
#    'favourites',
#    'portofolio']],
#  ['landscape', [], ['landscapes', 'landscaping', 'lanscape'], ['scenery']],
#  ['spine',
#   [],
#   ['swine', 'spin'],
#   ['devi', 'sprites', 'platformer', 'indiedev', 'tracer', 'idle']],
#  ['thank',
#   [],
#   ['than', 'thanks'],
#   ['thankyou', 'sadegh-eidi', 'say', 'thankful', 'thanksgiving', 'you']],
#  ['welcome', [], [], ['start', 'sadegh-eidi']],
#  ['protopie',
#   [],
#   [],
#   ['prototypes',
#    'preferences',
#    'iphones',
#    'prototyping',
#    'iosapp',
#    'xcode',
#    'switcher',
#    'to-do',
#    'touchid',
#    'translate',
#    'musicapp',
#    'flinto',
#    'ridesharing',
#    'recorder',
#    'microanimation',
#    'ixd',
#    'iwatch',
#    'prototype',
#    'vui',
#    'tvapp']],
#  ['about', [], [], ['careers', 'contact']],
#  ['me', [], [], []],
#  ['binding',
#   [],
#   ['bidding', 'brending'],
#   ['classification',
#    'published',
#    'dramatic',
#    'lembas',
#    'vending',
#    'sending',
#    'lado',
#    'crowdfunding',
#    'finding',
#    'wysiwyg',
#    'pierre',
#    'bulletin',
#    'issue',
#    'contents',
#    'lending',
#    'blackboard',
#    'funding',
#    'handbook',
#    'cookbook',
#    'e-book',
#    '7ninjas']],
#  ['interests',
#   [],
#   ['interesting', 'interest'],
#   ['masjid',
#    'blocky',
#    'intercom',
#    'colorful.',
#    'favourites',
#    'following',
#    'dekstop',
#    'broadcasting',
#    'cpr',
#    'mentoring',
#    'intuitive',
#    'explanation',
#    'sim',
#    'dreamers',
#    'interval',
#    'landingspage',
#    'pinterest']],
#  ['neon', [], [], []],
#  ['slopes',
#   [],
#   ['slope'],
#   ['mountaineering',
#    'vibrations',
#    'orienteering',
#    'warren',
#    'wales',
#    'work-in-progress',
#    'gondola',
#    'smoky',
#    'topo',
#    'snowboarder',
#    'snowboards',
#    'smore',
#    'skier',
#    'screamin',
#    'wyoming']],
#  ['snowboarding',
#   [],
#   ['snowboard', 'snowboarder', 'snowboards'],
#   ['switzerland',
#    'pyeongchang',
#    'trails',
#    'moosesnowboards',
#    'skiing',
#    'slopes',
#    'skier',
#    'ski',
#    'rollers',
#    'slope',
#    'wyoming']],
#  ['fruit',
#   [],
#   ['fruits', 'fruity'],
#   ['lemon', 'juicy', 'juice', 'grapefruit']],
#  ['vibes',
#   [],
#   ['vibe'],
#   ['wavvy', 'lyric', 'psy', 'witchy', 'wavy', 'shakespeare', 'wtf']],
#  ['wordmark', [], ['wordmarks', 'workmark'], ['submark', 'trademark']],
#  ['classic', [], ['classiccar', 'classical', 'classics', 'classy'], ['clasp']],
#  ['classy',
#   [],
#   ['class', 'classic'],
#   ['clasp', 'classical', 'classics', 'deluxe', 'chic', 'exclusive']],
#  ['elegant', [], ['elegance'], ['fancy']],
#  ['serif',
#   [],
#   ['serifs'],
#   ['slabserif',
#    'grotesk',
#    'sans-serif',
#    'sans',
#    'lowercase',
#    'slab',
#    'slab-serif',
#    'regular',
#    'sanserif',
#    'sansserif']],
#  ['typeface',
#   [],
#   ['typefaces'],
#   ['slabserif',
#    'typeform',
#    'typekit',
#    'sans',
#    'fontface',
#    'slab-serif',
#    'typegang',
#    'types']],
#  ['experiment', [], ['experiments', 'experimental'], ['experimentation']],
#  ['gradients', [], ['gradient', 'gradiente', 'gradient.'], []],
#  ['mountains',
#   [],
#   ['moutain', 'montain', 'mountain'],
#   ['mountaineering', 'fountain', 'mount', 'lake']],
#  ['sunrise',
#   ['suns'],
#   [],
#   ['sunset',
#    'sunburn',
#    'peaceful',
#    'moonrise',
#    'sunshine',
#    'sunlight',
#    'sand',
#    'palms',
#    'waterfall',
#    'windmill',
#    'shore',
#    'volcano',
#    'sanfrancisco',
#    'sip',
#    'mediterranean',
#    'sunburst',
#    'sun',
#    'sailboat',
#    'sundown']],
#  ['thick', [], [], ['roundel', 'rays', 'thicklines', 'utilitarian']],
#  ...]

# %%
import pandas as pd
name=['key','abbreviation','synonyms', "other"]
test=pd.DataFrame(columns=name,data=A)
print(test)
# Out:
#                           key abbreviation  \
# 0                         003           []
# 1                          30           []
# 2                        days           []
# 3                          of           []
# 4                          ui           []
# 5                    colorful           []
# 6                       daily           []
# 7                     landing           []
# 8                        page           []
# 9                       music           []
# 10                      event           []
# 11                 collection           []
# 12                       icon           []
# 13                iconography           []
# 14                       line           []
# 15                     online           []
# 16                        set           []
# 17                       shop           []
# 18                      store           []
# 19                     canvas           []
# 20                        art           []
# 21                     design           []
# 22                   graffiti           []
# 23                    graphic           []
# 24                  hamburger           []
# 25               illustration           []
# 26                    stencil           []
# 27                   calendar           []
# 28                       date           []
# 29                    persian           []
# ...                       ...          ...
# 12212                    tvui           []
# 12213         rafikillustrate           []
# 12214                 lamaran           []
# 12215           muslimwedding           []
# 12216     pengajianpernikahan           []
# 12217               seserahan           []
# 12218            infinitycoin   [infiniti]
# 12219                  shaper           []
# 12220                  visula           []
# 12221                    avie           []
# 12222                   salva           []
# 12223                 bookart           []
# 12224               smartsign           []
# 12225           dise?ografico           []
# 12226                   cesar           []
# 12227                  chavez           []
# 12228                wasiswas           []
# 12229                 dalaman           []
# 12230               transferi           []
# 12231                    rici           []
# 12232           urbanplanning           []
# 12233      tatyanakomarovaart           []
# 12234               modernizr           []
# 12235                     cvi           []
# 12236                 iwd2018           []
# 12237                 resumes           []
# 12238  internationalwomensday           []
# 12239          keychaindesign           []
# 12240                  rickyx           []
# 12241                  kuyper           []
#
#                                                 synonyms  \
# 0                                                     []
# 1                                                     []
# 2                                                     []
# 3                                                     []
# 4                                                     []
# 5                      [colorful., colourful, colorfull]
# 6                                                     []
# 7                                                     []
# 8                                         [page., pager]
# 9                                      [musical, musica]
# 10                                              [events]
# 11                    [collective, collect, collections]
# 12                                 [icon., icone, icono]
# 13                                                    []
# 14                                        [linen, lined]
# 15                                                    []
# 16                                                    []
# 17                                               [shops]
# 18                                              [stores]
# 19                                               [canva]
# 20                                                    []
# 21                                      [design., desig]
# 22                                                    []
# 23        [geographic, graphical, graphicart, graphics.]
# 24                                             [hamburg]
# 25     [illustration??, illustratio, illlustration, i...
# 26                                                    []
# 27                                            [calender]
# 28                                                    []
# 29                                                    []
# ...                                                  ...
# 12212                                                 []
# 12213                                                 []
# 12214                                                 []
# 12215                                                 []
# 12216                                                 []
# 12217                                                 []
# 12218                                                 []
# 12219                                            [shape]
# 12220                                          [visuals]
# 12221                                                 []
# 12222                                                 []
# 12223                                                 []
# 12224                                                 []
# 12225                                                 []
# 12226                                           [caesar]
# 12227                                                 []
# 12228                                                 []
# 12229                                                 []
# 12230                              [transfer, transfers]
# 12231                                                 []
# 12232                                                 []
# 12233                                                 []
# 12234                  [modernism, modernity, modernist]
# 12235                                                 []
# 12236                                                 []
# 12237                                           [resume]
# 12238                                                 []
# 12239                                                 []
# 12240                                            [ricky]
# 12241                                                 []
#
#                                                    other
# 0      [100ui, 030, 100daysofui, 085, 032, day004, 00...
# 1             [day4, 030, 014, 011, day2, days, -, day5]
# 2      [day4, day3, day2, 36, 36days, 30, 100days, da...
# 3                                                     []
# 4        [ux.ui, ui., uxui, ui-ux, ?ui, ux-ui, ui8, uix]
# 5                                           [colorbeats]
# 6      [daily100, dailyui014, dailyui015, uidaily, da...
# 7              [landingpage, landing-page, landingspage]
# 8      [fullpage, landing-page, loginpage, webpage, m...
# 9            [musician, musicians, musicapp, musiccloth]
# 10                                                    []
# 11                                                    []
# 12                            [favicon, icons., icon??i]
# 13     [icon., icone, icons., iconpack, icono, icon??...
# 14                          [wantline, one-line, lineal]
# 15             [onlineshop, onlineshopping, onlinestore]
# 16                                                    []
# 17                    [e-shop, eshop, shopping., shoply]
# 18                    [restore, onlinestore, storefront]
# 19                                             [acrylic]
# 20                                               [artph]
# 21                            [designzillas, designuxui]
# 22                            [calligraffiti, streetart]
# 23     [graphique, graphicgraphic, fpgraphic, info-gr...
# 24                     [cook, eat, cheeseburger, burger]
# 25                      [mrugaillustration, llustration]
# 26     [uppercase, slabserif, pairing, ttf, humanist,...
# 27                                        [calendar2018]
# 28                                          [datepicker]
# 29                                              [italic]
# ...                                                  ...
# 12212  [tvos, tavan, 049, androidtv, kap?, ??????????...
# 12213  [vegetation, monarch, illustrasi, illustraor, ...
# 12214  [sajadahmurah, matematika, oleholehumroh, saja...
# 12215  [sajadahmurah, tahlilan, weddings, souvenir, a...
# 12216  [sajadahmurah, matematika, oleholehumroh, saja...
# 12217  [sajadahmurah, matematika, oleholehumroh, saja...
# 12218  [bp, raiblocks, calculation, litecoin, infinit...
# 12219  [blundlund, hebert, dieta, golem, karl, lunchb...
# 12220  [trajlov, visuelle, digit, moments, visual, ot...
# 12221  [arabesque, bach, av, alvaromelgosa, bristol, ...
# 12222           [essay, acting, salvador, educate, enem]
# 12223  [bookblog, bookstore, bookazine, bookcover, bo...
# 12224  [selfbranding, burma, keychaindesign, 1957, cu...
# 12225  [blundlund, dise?o, grafico, imagotipo, bangla...
# 12226  [mardigras, housewarming, epiphany, masquerade...
# 12227  [mardigras, mardi, reggaeton, paddys, psdfreeb...
# 12228  [ne, ttf, sioux, sexuality, virgin, patience, ...
# 12229  [transferi, he-man, tavan, metamodernist, youc...
# 12230  [dekal, tavan, firma, kap?, transactions, ?irk...
# 12231  [arch-viz, exterior, butterbay, embassy, cheng...
# 12232  [arch-viz, butterbay, triomphe, embassy, cheng...
# 12233  [tulips, bouquets, surfacepattern, eucalyptus,...
# 12234  [angularjs, jquery, odoo, 7leran, psd-to-html,...
# 12235  [latter, @, flat-logo, cabinets, idenity, busi...
# 12236  [2016, resistance, 2k18, 2013, phil, mwc2018, ...
# 12237  [cakeresume, use, freepsd, freemockup, ms, env...
# 12238  [international, earring, vexel, ego, melanin, ...
# 12239  [burma, smartsign, beardedman, avie, massimovi...
# 12240  [toe, critical, compositor, teenagers, jeremy,...
# 12241  [advocates, hyper, toe, blundlund.co., clark, ...
#
# [12242 rows x 4 columns]
